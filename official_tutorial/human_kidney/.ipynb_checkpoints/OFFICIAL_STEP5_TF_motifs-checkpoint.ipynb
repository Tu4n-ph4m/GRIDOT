# %%
import scanpy as sc
import os
import warnings
warnings.filterwarnings("ignore")
import pandas
# import pyranges
# Set stderr to null to avoid strange messages from ray
import sys
_stderr = sys.stderr
null = open(os.devnull,'wb')


# from loomxpy.loomxpy import SCopeLoom
# from pycisTopic.loom import *
import itertools
import anndata
import pandas as pd
# Load cistarget functions
from pycistarget.motif_enrichment_cistarget import *

# %%
outfile = f"./results/CRE_gene/CRE_gene_cell_population.tsv"

# %%
results = pd.read_csv(outfile, sep ='\t',index_col = 0)

# %%
results
# Out:
#                            CRE       Gene  rss_ratio     ftest   dist
# 0           chr1:778219-779393  LINC01409   0.995304  1.000000    528
# 1           chr1:778219-779393  LINC01128   1.005714  0.985046  45745
# 2           chr1:826772-827922  LINC01409   0.995121  1.000000  48025
# 3           chr1:826772-827922  LINC01128   1.005626  0.986449   1634
# 4           chr1:826772-827922  LINC02593   0.988154  1.000000  88943
# ...                        ...        ...        ...       ...    ...
# 194286  chrY:12904476-12905923      DDX3Y   0.994154  1.000000    368
# 194287  chrY:13282692-13283155        UTY   1.001180  1.000000  48115
# 194288  chrY:14524430-14524989     NLGN4Y   0.997252  1.000000   1857
# 194289  chrY:19744506-19745162      KDM5D   0.999905  1.000000  40641
# 194290  chrY:20575346-20576097     EIF1AY   0.999581  1.000000    321
#
# [194291 rows x 5 columns]

# %%
split_columns = results['CRE'].str.split(':|-', expand=True)
split_columns.columns = ['chr', 'start', 'end']  # Rename the new columns
results = pd.concat([results, split_columns], axis=1)
# df.rename(columns={'Y_names': 'new_column_name'}, inplace=True)
grouped = results.groupby("Gene")
results = results[['chr', 'start', 'end']]
# results['chr'] = 'chr'+results['chr']

print(results)
# Out:
#          chr     start       end
# 0       chr1    778219    779393
# 1       chr1    778219    779393
# 2       chr1    826772    827922
# 3       chr1    826772    827922
# 4       chr1    826772    827922
# ...      ...       ...       ...
# 194286  chrY  12904476  12905923
# 194287  chrY  13282692  13283155
# 194288  chrY  14524430  14524989
# 194289  chrY  19744506  19745162
# 194290  chrY  20575346  20576097
#
# [194291 rows x 3 columns]

# %%
import os
outDir =f'./results/TF_motif/bedfile/'
if not os.path.exists(outDir):
    print(outDir)
    os.makedirs(outDir)
# Out:
# ./results/TF_motif/bedfile/

# %%
top_percentile = 0.1

for category, group in grouped:

    if "/" in category:
        continue
    threshold_value = group['rss_ratio'].quantile(1 - top_percentile)

    top_rows = group[group['rss_ratio'] >= threshold_value]
    top_rows = top_rows[['chr', 'start', 'end']]
    top_rows.to_csv(outDir+category+".bed",sep="\t",index=False)

# %%
import pyranges as pr
import os
path_to_region_sets = outDir
print(path_to_region_sets)
region_sets_files = os.listdir(path_to_region_sets)
region_sets = {}
i=0
for x in region_sets_files:
#     print(x)
#     x.replace('.bed', '')
    temp_doc = pr.read_bed(os.path.join(path_to_region_sets, x)) 
#     print(x,len(temp_doc))
    if len(temp_doc) <5:
        continue
    else:
        i+=1
#         print(len(temp_doc),i)
        region_sets[x.replace('.bed', '')] = temp_doc
# Out:
# ./results_OT/results/bedfile/

# %%
db = '../../gridnet/pbmc/hg38_screen_v10_clust.regions_vs_motifs.rankings.feather'
# ctx_db = cisTargetDatabase(db, first_half_dict)

# %%
def identify_all_TF_gene_link_candidates(rna_TF_dictionary):

    # Flattening the dictionary
    flat_data = [(v, k) for k, lst in rna_TF_dictionary.items() for v in lst ]

    # Creating DataFrame
    df = pd.DataFrame(flat_data, columns=['TF', 'Gene'])
    return df

# %%
outDir =f'./results_OT/results/TF_gene/'
if not os.path.exists(outDir):
    os.makedirs(outDir)

# %%
# Out:
# 666
# 0
# reading database
# 2025-01-28 13:05:08,106 cisTarget    INFO     Reading cisTarget database
# cistarget
# (ctx_internal_ray pid=2120775) 2025-01-28 13:11:21,544 cisTarget    INFO     Running cisTarget for ABCC3 which has 12 regions
# (ctx_internal_ray pid=2120768) 2025-01-28 13:11:21,575 cisTarget    INFO     Running cisTarget for AFTPH which has 22 regions
# (ctx_internal_ray pid=2120773) 2025-01-28 13:11:22,507 cisTarget    INFO     Running cisTarget for AHRR which has 9 regions
# (ctx_internal_ray pid=2120770) 2025-01-28 13:12:45,038 cisTarget    INFO     Annotating motifs for AKT2
# (ctx_internal_ray pid=2120762) 2025-01-28 13:11:24,269 cisTarget    INFO     Running cisTarget for ANKRD33B which has 16 regions [repeated 17x across cluster]
# (ctx_internal_ray pid=2120768) 2025-01-28 13:12:47,205 cisTarget    INFO     Annotating motifs for AFTPH
# (ctx_internal_ray pid=2120770) 2025-01-28 13:12:53,370 cisTarget    INFO     Getting cistromes for AKT2
# (ctx_internal_ray pid=2120774) 2025-01-28 13:12:47,530 cisTarget    INFO     Annotating motifs for ACTN1 [repeated 3x across cluster]
# (ctx_internal_ray pid=2120770) 2025-01-28 13:12:55,399 cisTarget    INFO     Running cisTarget for ANKRD40 which has 12 regions
# (ctx_internal_ray pid=2120768) 2025-01-28 13:12:56,290 cisTarget    INFO     Getting cistromes for AFTPH
# (ctx_internal_ray pid=2120775) 2025-01-28 13:12:56,580 cisTarget    INFO     Getting cistromes for ABCC3 [repeated 2x across cluster]
# (ctx_internal_ray pid=2120768) 2025-01-28 13:12:59,558 cisTarget    INFO     Running cisTarget for ANPEP which has 8 regions
# (ctx_internal_ray pid=2120767) 2025-01-28 13:13:03,344 cisTarget    INFO     Annotating motifs for ANKRD12
# (ctx_internal_ray pid=2120775) 2025-01-28 13:12:59,380 cisTarget    INFO     Running cisTarget for ANKS3 which has 23 regions [repeated 2x across cluster]
# (ctx_internal_ray pid=2120774) 2025-01-28 13:13:04,873 cisTarget    INFO     Getting cistromes for ACTN1
# (ctx_internal_ray pid=2120774) 2025-01-28 13:13:08,788 cisTarget    INFO     Running cisTarget for ANTXR1 which has 8 regions
# (ctx_internal_ray pid=2120762) 2025-01-28 13:13:14,027 cisTarget    INFO     Annotating motifs for ANKRD33B
# (ctx_internal_ray pid=2120767) 2025-01-28 13:13:14,143 cisTarget    INFO     Getting cistromes for ANKRD12
# (ctx_internal_ray pid=2120767) 2025-01-28 13:13:16,672 cisTarget    INFO     Running cisTarget for AP1S3 which has 9 regions
# (ctx_internal_ray pid=2120762) 2025-01-28 13:13:24,978 cisTarget    INFO     Getting cistromes for ANKRD33B
# (ctx_internal_ray pid=2120769) 2025-01-28 13:13:28,445 cisTarget    INFO     Annotating motifs for ALS2CL
# (ctx_internal_ray pid=2120762) 2025-01-28 13:13:29,552 cisTarget    INFO     Running cisTarget for AP3S2 which has 9 regions
# (ctx_internal_ray pid=2120764) 2025-01-28 13:13:33,472 cisTarget    INFO     Annotating motifs for ANKRD29 [repeated 2x across cluster]
# (ctx_internal_ray pid=2120773) 2025-01-28 13:13:38,093 cisTarget    INFO     Annotating motifs for AHRR
# (ctx_internal_ray pid=2120769) 2025-01-28 13:13:40,584 cisTarget    INFO     Getting cistromes for ALS2CL
# (ctx_internal_ray pid=2120778) 2025-01-28 13:13:35,039 cisTarget    INFO     Annotating motifs for ACO2
# (ctx_internal_ray pid=2120769) 2025-01-28 13:13:42,793 cisTarget    INFO     Running cisTarget for APBB1 which has 21 regions
# (ctx_internal_ray pid=2120781) 2025-01-28 13:13:45,315 cisTarget    INFO     Annotating motifs for AGAP1
# (ctx_internal_ray pid=2120764) 2025-01-28 13:13:45,357 cisTarget    INFO     Getting cistromes for ANKRD29 [repeated 2x across cluster]
# (ctx_internal_ray pid=2120764) 2025-01-28 13:13:49,779 cisTarget    INFO     Running cisTarget for APOL2 which has 43 regions [repeated 2x across cluster]
# (ctx_internal_ray pid=2120778) 2025-01-28 13:13:46,736 cisTarget    INFO     Getting cistromes for ACO2
# (ctx_internal_ray pid=2120776) 2025-01-28 13:13:54,344 cisTarget    INFO     Annotating motifs for ADIPOR1
# (ctx_internal_ray pid=2120781) 2025-01-28 13:13:55,855 cisTarget    INFO     Getting cistromes for AGAP1
# (ctx_internal_ray pid=2120778) 2025-01-28 13:13:51,312 cisTarget    INFO     Running cisTarget for APOL3 which has 4 regions
# (ctx_internal_ray pid=2120773) 2025-01-28 13:13:56,419 cisTarget    INFO     Getting cistromes for AHRR
# (ctx_internal_ray pid=2120781) 2025-01-28 13:13:56,533 cisTarget    INFO     Running cisTarget for ARAP3 which has 5 regions
# (ctx_internal_ray pid=2120770) 2025-01-28 13:13:59,218 cisTarget    INFO     Annotating motifs for ANKRD40 [repeated 2x across cluster]
# (ctx_internal_ray pid=2120776) 2025-01-28 13:14:02,800 cisTarget    INFO     Getting cistromes for ADIPOR1
# (ctx_internal_ray pid=2120773) 2025-01-28 13:14:00,497 cisTarget    INFO     Running cisTarget for ARHGAP21 which has 4 regions
# (ctx_internal_ray pid=2120776) 2025-01-28 13:14:05,791 cisTarget    INFO     Running cisTarget for ARHGAP29 which has 30 regions
# (ctx_internal_ray pid=2120779) 2025-01-28 13:14:06,565 cisTarget    INFO     Annotating motifs for ABCA7
# (ctx_internal_ray pid=2120768) 2025-01-28 13:14:06,545 cisTarget    INFO     Annotating motifs for ANPEP
# (ctx_internal_ray pid=2120772) 2025-01-28 13:14:06,920 cisTarget    INFO     Getting cistromes for ALKBH4
# (ctx_internal_ray pid=2120772) 2025-01-28 13:14:09,636 cisTarget    INFO     Running cisTarget for ARHGAP32 which has 22 regions
# (ctx_internal_ray pid=2120775) 2025-01-28 13:14:12,921 cisTarget    INFO     Annotating motifs for ANKS3 [repeated 2x across cluster]
# (ctx_internal_ray pid=2120770) 2025-01-28 13:14:10,671 cisTarget    INFO     Getting cistromes for ANKRD40
# (ctx_internal_ray pid=2120770) 2025-01-28 13:14:13,220 cisTarget    INFO     Running cisTarget for ARHGAP45 which has 65 regions
# (ctx_internal_ray pid=2120768) 2025-01-28 13:14:16,546 cisTarget    INFO     Getting cistromes for ANPEP
# (ctx_internal_ray pid=2120779) 2025-01-28 13:14:16,867 cisTarget    INFO     Getting cistromes for ABCA7
# (ctx_internal_ray pid=2120765) 2025-01-28 13:14:13,775 cisTarget    INFO     Annotating motifs for ANKRD46
# (ctx_internal_ray pid=2120779) 2025-01-28 13:14:18,601 cisTarget    INFO     Running cisTarget for ARHGEF17 which has 10 regions [repeated 2x across cluster]
# (ctx_internal_ray pid=2120767) 2025-01-28 13:14:19,340 cisTarget    INFO     Annotating motifs for AP1S3
# (ctx_internal_ray pid=2120775) 2025-01-28 13:14:24,786 cisTarget    INFO     Getting cistromes for ANKS3 [repeated 2x across cluster]
# (ctx_internal_ray pid=2120763) 2025-01-28 13:14:21,226 cisTarget    INFO     Running cisTarget for ARHGEF40 which has 15 regions
# (ctx_internal_ray pid=2120777) 2025-01-28 13:14:19,733 cisTarget    INFO     Annotating motifs for ADAM15
# (ctx_internal_ray pid=2120774) 2025-01-28 13:14:25,959 cisTarget    INFO     Annotating motifs for ANTXR1
# (ctx_internal_ray pid=2120775) 2025-01-28 13:14:29,883 cisTarget    INFO     Running cisTarget for ARID3B which has 12 regions
# (ctx_internal_ray pid=2120765) 2025-01-28 13:14:25,694 cisTarget    INFO     Getting cistromes for ANKRD46
# (ctx_internal_ray pid=2120767) 2025-01-28 13:14:29,915 cisTarget    INFO     Getting cistromes for AP1S3
# (ctx_internal_ray pid=2120780) 2025-01-28 13:14:30,365 cisTarget    INFO     Annotating motifs for ACOT9
# (ctx_internal_ray pid=2120771) 2025-01-28 13:14:31,742 cisTarget    INFO     Annotating motifs for AGPAT2
# (ctx_internal_ray pid=2120777) 2025-01-28 13:14:37,455 cisTarget    INFO     Running cisTarget for ARSA which has 38 regions
# (ctx_internal_ray pid=2120767) 2025-01-28 13:14:31,069 cisTarget    INFO     Running cisTarget for ARMT1 which has 13 regions [repeated 2x across cluster]
# (ctx_internal_ray pid=2120777) 2025-01-28 13:14:32,841 cisTarget    INFO     Getting cistromes for ADAM15
# (ctx_internal_ray pid=2120774) 2025-01-28 13:14:38,083 cisTarget    INFO     Getting cistromes for ANTXR1
# (ctx_internal_ray pid=2120774) 2025-01-28 13:14:41,516 cisTarget    INFO     Running cisTarget for ASAP2 which has 10 regions
# (ctx_internal_ray pid=2120780) 2025-01-28 13:14:43,326 cisTarget    INFO     Getting cistromes for ACOT9
# (ctx_internal_ray pid=2120771) 2025-01-28 13:14:44,264 cisTarget    INFO     Getting cistromes for AGPAT2
# (ctx_internal_ray pid=2120771) 2025-01-28 13:14:48,558 cisTarget    INFO     Running cisTarget for ASB13 which has 16 regions
# (ctx_internal_ray pid=2120764) 2025-01-28 13:14:53,637 cisTarget    INFO     Annotating motifs for APOL2
# (ctx_internal_ray pid=2120780) 2025-01-28 13:14:48,661 cisTarget    INFO     Running cisTarget for ASB16-AS1 which has 7 regions
# (ctx_internal_ray pid=2120764) 2025-01-28 13:15:03,321 cisTarget    INFO     Getting cistromes for APOL2
# (ctx_internal_ray pid=2120762) 2025-01-28 13:14:58,557 cisTarget    INFO     Annotating motifs for AP3S2
# (ctx_internal_ray pid=2120764) 2025-01-28 13:15:03,919 cisTarget    INFO     Running cisTarget for ASS1 which has 42 regions
# (ctx_internal_ray pid=2120762) 2025-01-28 13:15:08,214 cisTarget    INFO     Getting cistromes for AP3S2
# (ctx_internal_ray pid=2120762) 2025-01-28 13:15:10,662 cisTarget    INFO     Running cisTarget for ATP11A which has 13 regions
# (ctx_internal_ray pid=2120776) 2025-01-28 13:15:14,131 cisTarget    INFO     Annotating motifs for ARHGAP29
# (ctx_internal_ray pid=2120776) 2025-01-28 13:15:20,992 cisTarget    INFO     Getting cistromes for ARHGAP29
# (ctx_internal_ray pid=2120776) 2025-01-28 13:15:21,743 cisTarget    INFO     Running cisTarget for ATP5F1B which has 17 regions
# (ctx_internal_ray pid=2120781) 2025-01-28 13:15:26,307 cisTarget    INFO     Annotating motifs for ARAP3
# (ctx_internal_ray pid=2120778) 2025-01-28 13:15:38,431 cisTarget    INFO     Annotating motifs for APOL3 [repeated 3x across cluster]
# (ctx_internal_ray pid=2120781) 2025-01-28 13:15:38,673 cisTarget    INFO     Getting cistromes for ARAP3
# (ctx_internal_ray pid=2120781) 2025-01-28 13:15:39,548 cisTarget    INFO     Running cisTarget for ATP6V0D1 which has 20 regions
# (ctx_internal_ray pid=2120774) 2025-01-28 13:15:43,664 cisTarget    INFO     Running cisTarget for AVIL which has 9 regions
# (ctx_internal_ray pid=2120767) 2025-01-28 13:15:39,303 cisTarget    INFO     Annotating motifs for ARMT1
# (ctx_internal_ray pid=2120774) 2025-01-28 13:15:41,576 cisTarget    INFO     Getting cistromes for ASAP2 [repeated 2x across cluster]
# (ctx_internal_ray pid=2120769) 2025-01-28 13:15:45,830 cisTarget    INFO     Running cisTarget for B4GALT7 which has 9 regions
# (ctx_internal_ray pid=2120778) 2025-01-28 13:15:50,376 cisTarget    INFO     Getting cistromes for APOL3
# (ctx_internal_ray pid=2120767) 2025-01-28 13:15:50,890 cisTarget    INFO     Getting cistromes for ARMT1
# (ctx_internal_ray pid=2120768) 2025-01-28 13:15:51,576 cisTarget    INFO     Annotating motifs for ARHGEF10L
# (ctx_internal_ray pid=2120778) 2025-01-28 13:15:51,893 cisTarget    INFO     Running cisTarget for BAG3 which has 16 regions
# (ctx_internal_ray pid=2120768) 2025-01-28 13:16:03,716 cisTarget    INFO     Getting cistromes for ARHGEF10L
# (ctx_internal_ray pid=2120764) 2025-01-28 13:15:53,397 cisTarget    INFO     Annotating motifs for ASS1 [repeated 2x across cluster]
# (ctx_internal_ray pid=2120767) 2025-01-28 13:15:54,766 cisTarget    INFO     Running cisTarget for BBS12 which has 11 regions
# (ctx_internal_ray pid=2120764) 2025-01-28 13:16:05,389 cisTarget    INFO     Getting cistromes for ASS1
# (ctx_internal_ray pid=2120764) 2025-01-28 13:16:06,296 cisTarget    INFO     Running cisTarget for BCL2L11 which has 19 regions
# (ctx_internal_ray pid=2120772) 2025-01-28 13:16:09,645 cisTarget    INFO     Annotating motifs for ARHGAP32 [repeated 3x across cluster]
# (ctx_internal_ray pid=2120773) 2025-01-28 13:16:07,042 cisTarget    INFO     Getting cistromes for ARHGAP21
# (ctx_internal_ray pid=2120773) 2025-01-28 13:16:08,208 cisTarget    INFO     Running cisTarget for BDH2 which has 15 regions [repeated 2x across cluster]
# (ctx_internal_ray pid=2120779) 2025-01-28 13:16:18,464 cisTarget    INFO     Getting cistromes for ARHGEF17
# (ctx_internal_ray pid=2120770) 2025-01-28 13:16:14,590 cisTarget    INFO     Annotating motifs for ARHGAP45
# (ctx_internal_ray pid=2120762) 2025-01-28 13:16:19,719 cisTarget    INFO     Annotating motifs for ATP11A
# (ctx_internal_ray pid=2120779) 2025-01-28 13:16:21,660 cisTarget    INFO     Running cisTarget for BHMT2 which has 9 regions
# (ctx_internal_ray pid=2120772) 2025-01-28 13:16:22,714 cisTarget    INFO     Getting cistromes for ARHGAP32 [repeated 2x across cluster]
# (ctx_internal_ray pid=2120765) 2025-01-28 13:16:26,280 cisTarget    INFO     Annotating motifs for ARID4B
# (ctx_internal_ray pid=2120777) 2025-01-28 13:16:27,406 cisTarget    INFO     Annotating motifs for ARSA
# (ctx_internal_ray pid=2120766) 2025-01-28 13:16:21,889 cisTarget    INFO     Running cisTarget for BOD1 which has 12 regions
# (ctx_internal_ray pid=2120772) 2025-01-28 13:16:27,944 cisTarget    INFO     Running cisTarget for BTBD6 which has 6 regions
# (ctx_internal_ray pid=2120771) 2025-01-28 13:16:28,228 cisTarget    INFO     Annotating motifs for ASB13
# (ctx_internal_ray pid=2120762) 2025-01-28 13:16:31,445 cisTarget    INFO     Getting cistromes for ATP11A [repeated 2x across cluster]
# (ctx_internal_ray pid=2120762) 2025-01-28 13:16:34,692 cisTarget    INFO     Running cisTarget for BTN3A1 which has 16 regions [repeated 2x across cluster]
# (ctx_internal_ray pid=2120763) 2025-01-28 13:16:31,982 cisTarget    INFO     Annotating motifs for ARHGEF40
# (ctx_internal_ray pid=2120780) 2025-01-28 13:16:35,913 cisTarget    INFO     Annotating motifs for ASB16-AS1
# (ctx_internal_ray pid=2120777) 2025-01-28 13:16:38,484 cisTarget    INFO     Getting cistromes for ARSA
# (ctx_internal_ray pid=2120765) 2025-01-28 13:16:38,455 cisTarget    INFO     Getting cistromes for ARID4B
# (ctx_internal_ray pid=2120777) 2025-01-28 13:16:40,343 cisTarget    INFO     Running cisTarget for C1QTNF7 which has 9 regions
# (ctx_internal_ray pid=2120765) 2025-01-28 13:16:43,035 cisTarget    INFO     Running cisTarget for C2orf42 which has 14 regions
# (ctx_internal_ray pid=2120763) 2025-01-28 13:16:44,306 cisTarget    INFO     Getting cistromes for ARHGEF40 [repeated 2x across cluster]
# (ctx_internal_ray pid=2120763) 2025-01-28 13:16:48,149 cisTarget    INFO     Running cisTarget for C5orf15 which has 19 regions [repeated 2x across cluster]
# (ctx_internal_ray pid=2120776) 2025-01-28 13:16:49,855 cisTarget    INFO     Annotating motifs for ATP5F1B
# (ctx_internal_ray pid=2120780) 2025-01-28 13:16:53,009 cisTarget    INFO     Getting cistromes for ASB16-AS1
# (ctx_internal_ray pid=2120780) 2025-01-28 13:16:55,795 cisTarget    INFO     Running cisTarget for C9orf106 which has 10 regions
# (ctx_internal_ray pid=2120775) 2025-01-28 13:16:50,593 cisTarget    INFO     Annotating motifs for ARID3B
# (ctx_internal_ray pid=2120776) 2025-01-28 13:17:03,620 cisTarget    INFO     Getting cistromes for ATP5F1B
# (ctx_internal_ray pid=2120775) 2025-01-28 13:17:04,733 cisTarget    INFO     Getting cistromes for ARID3B
# (ctx_internal_ray pid=2120769) 2025-01-28 13:17:06,598 cisTarget    INFO     Annotating motifs for B4GALT7
# (ctx_internal_ray pid=2120776) 2025-01-28 13:17:08,572 cisTarget    INFO     Running cisTarget for CA12 which has 9 regions
# (ctx_internal_ray pid=2120781) 2025-01-28 13:17:11,602 cisTarget    INFO     Annotating motifs for ATP6V0D1
# (ctx_internal_ray pid=2120769) 2025-01-28 13:17:20,005 cisTarget    INFO     Getting cistromes for B4GALT7
# (ctx_internal_ray pid=2120775) 2025-01-28 13:17:09,710 cisTarget    INFO     Running cisTarget for CACNA1H which has 38 regions
# (ctx_internal_ray pid=2120769) 2025-01-28 13:17:23,723 cisTarget    INFO     Running cisTarget for CACNA2D3 which has 7 regions
# (ctx_internal_ray pid=2120768) 2025-01-28 13:17:25,561 cisTarget    INFO     Annotating motifs for BCL9L
# (ctx_internal_ray pid=2120781) 2025-01-28 13:17:24,598 cisTarget    INFO     Getting cistromes for ATP6V0D1
# (ctx_internal_ray pid=2120774) 2025-01-28 13:17:27,565 cisTarget    INFO     Annotating motifs for AVIL
# (ctx_internal_ray pid=2120781) 2025-01-28 13:17:29,602 cisTarget    INFO     Running cisTarget for CAHM which has 19 regions
# (ctx_internal_ray pid=2120768) 2025-01-28 13:17:37,672 cisTarget    INFO     Getting cistromes for BCL9L
# (ctx_internal_ray pid=2120767) 2025-01-28 13:17:28,689 cisTarget    INFO     Annotating motifs for BBS12
# (ctx_internal_ray pid=2120768) 2025-01-28 13:17:40,332 cisTarget    INFO     Running cisTarget for CAMKK1 which has 11 regions
# (ctx_internal_ray pid=2120774) 2025-01-28 13:17:41,325 cisTarget    INFO     Getting cistromes for AVIL
# (ctx_internal_ray pid=2120778) 2025-01-28 13:17:41,587 cisTarget    INFO     Annotating motifs for BAG3
# (ctx_internal_ray pid=2120774) 2025-01-28 13:17:44,896 cisTarget    INFO     Running cisTarget for CASR which has 6 regions
# (ctx_internal_ray pid=2120767) 2025-01-28 13:17:41,978 cisTarget    INFO     Getting cistromes for BBS12
# (ctx_internal_ray pid=2120767) 2025-01-28 13:17:47,194 cisTarget    INFO     Running cisTarget for CASZ1 which has 10 regions
# (ctx_internal_ray pid=2120778) 2025-01-28 13:17:54,935 cisTarget    INFO     Getting cistromes for BAG3
# (ctx_internal_ray pid=2120778) 2025-01-28 13:17:57,988 cisTarget    INFO     Running cisTarget for CBX5 which has 11 regions
# (ctx_internal_ray pid=2120764) 2025-01-28 13:17:59,568 cisTarget    INFO     Annotating motifs for BCL2L11
# (ctx_internal_ray pid=2120779) 2025-01-28 13:18:04,865 cisTarget    INFO     Annotating motifs for BHMT2 [repeated 2x across cluster]
# (ctx_internal_ray pid=2120765) 2025-01-28 13:18:10,093 cisTarget    INFO     Annotating motifs for C2orf42 [repeated 3x across cluster]
# (ctx_internal_ray pid=2120762) 2025-01-28 13:18:12,741 cisTarget    INFO     Getting cistromes for BTN3A1
# (ctx_internal_ray pid=2120762) 2025-01-28 13:18:14,867 cisTarget    INFO     Running cisTarget for CCAR2 which has 20 regions
# (ctx_internal_ray pid=2120763) 2025-01-28 13:18:17,034 cisTarget    INFO     Annotating motifs for C5orf15
# (ctx_internal_ray pid=2120771) 2025-01-28 13:18:17,838 cisTarget    INFO     Getting cistromes for C5 [repeated 3x across cluster]
# (ctx_internal_ray pid=2120770) 2025-01-28 13:18:18,175 cisTarget    INFO     Annotating motifs for BTBD9
# (ctx_internal_ray pid=2120771) 2025-01-28 13:18:19,703 cisTarget    INFO     Running cisTarget for CCDC82 which has 33 regions [repeated 3x across cluster]
# (ctx_internal_ray pid=2120764) 2025-01-28 13:18:20,085 cisTarget    INFO     Getting cistromes for BCL2L11 [repeated 2x across cluster]
# (ctx_internal_ray pid=2120776) 2025-01-28 13:18:23,719 cisTarget    INFO     Annotating motifs for CA12 [repeated 3x across cluster]
# (ctx_internal_ray pid=2120781) 2025-01-28 13:18:25,349 cisTarget    INFO     Annotating motifs for CAHM
# (ctx_internal_ray pid=2120764) 2025-01-28 13:18:23,783 cisTarget    INFO     Running cisTarget for CCNG2 which has 25 regions [repeated 2x across cluster]
# (ctx_internal_ray pid=2120763) 2025-01-28 13:18:28,982 cisTarget    INFO     Getting cistromes for C5orf15
# (ctx_internal_ray pid=2120766) 2025-01-28 13:18:24,490 cisTarget    INFO     Annotating motifs for BOD1
# (ctx_internal_ray pid=2120770) 2025-01-28 13:18:30,500 cisTarget    INFO     Getting cistromes for BTBD9
# (ctx_internal_ray pid=2120763) 2025-01-28 13:18:32,647 cisTarget    INFO     Running cisTarget for CD59 which has 16 regions
# (ctx_internal_ray pid=2120772) 2025-01-28 13:18:32,663 cisTarget    INFO     Getting cistromes for BTBD6 [repeated 2x across cluster]
# (ctx_internal_ray pid=2120781) 2025-01-28 13:18:37,509 cisTarget    INFO     Getting cistromes for CAHM
# (ctx_internal_ray pid=2120772) 2025-01-28 13:18:35,576 cisTarget    INFO     Running cisTarget for CDC5L which has 17 regions [repeated 3x across cluster]
# (ctx_internal_ray pid=2120775) 2025-01-28 13:18:41,278 cisTarget    INFO     Annotating motifs for CACNA1H
# (ctx_internal_ray pid=2120766) 2025-01-28 13:18:37,908 cisTarget    INFO     Getting cistromes for BOD1 [repeated 2x across cluster]
# (ctx_internal_ray pid=2120774) 2025-01-28 13:18:44,152 cisTarget    INFO     Annotating motifs for CASR
# (ctx_internal_ray pid=2120766) 2025-01-28 13:18:41,268 cisTarget    INFO     Running cisTarget for CDHR5 which has 56 regions [repeated 3x across cluster]
# (ctx_internal_ray pid=2120780) 2025-01-28 13:18:53,124 cisTarget    INFO     Annotating motifs for C9orf106
# (ctx_internal_ray pid=2120775) 2025-01-28 13:18:54,497 cisTarget    INFO     Getting cistromes for CACNA1H
# (ctx_internal_ray pid=2120774) 2025-01-28 13:18:56,932 cisTarget    INFO     Getting cistromes for CASR
# (ctx_internal_ray pid=2120775) 2025-01-28 13:18:58,105 cisTarget    INFO     Running cisTarget for CDK3 which has 33 regions
# (ctx_internal_ray pid=2120769) 2025-01-28 13:19:01,229 cisTarget    INFO     Annotating motifs for CACNA2D3
# (ctx_internal_ray pid=2120780) 2025-01-28 13:19:05,025 cisTarget    INFO     Getting cistromes for C9orf106
# (ctx_internal_ray pid=2120774) 2025-01-28 13:18:58,180 cisTarget    INFO     Running cisTarget for CDK5RAP3 which has 7 regions
# (ctx_internal_ray pid=2120780) 2025-01-28 13:19:08,399 cisTarget    INFO     Running cisTarget for CEBPG which has 10 regions
# (ctx_internal_ray pid=2120768) 2025-01-28 13:19:04,969 cisTarget    INFO     Annotating motifs for CAMKK1
# (ctx_internal_ray pid=2120769) 2025-01-28 13:19:12,801 cisTarget    INFO     Getting cistromes for CACNA2D3
# (ctx_internal_ray pid=2120769) 2025-01-28 13:19:15,539 cisTarget    INFO     Running cisTarget for CGNL1 which has 11 regions
# (ctx_internal_ray pid=2120768) 2025-01-28 13:19:16,999 cisTarget    INFO     Getting cistromes for CAMKK1
# (ctx_internal_ray pid=2120768) 2025-01-28 13:19:22,535 cisTarget    INFO     Running cisTarget for CHAF1A which has 20 regions
# (ctx_internal_ray pid=2120762) 2025-01-28 13:19:32,032 cisTarget    INFO     Annotating motifs for CCAR2
# (ctx_internal_ray pid=2120762) 2025-01-28 13:19:43,243 cisTarget    INFO     Getting cistromes for CCAR2
# (ctx_internal_ray pid=2120762) 2025-01-28 13:19:44,942 cisTarget    INFO     Running cisTarget for CHID1 which has 96 regions
# (ctx_internal_ray pid=2120779) 2025-01-28 13:19:50,775 cisTarget    INFO     Annotating motifs for CCDC65
# (ctx_internal_ray pid=2120778) 2025-01-28 13:19:57,331 cisTarget    INFO     Annotating motifs for CBX5 [repeated 2x across cluster]
# (ctx_internal_ray pid=2120779) 2025-01-28 13:20:03,681 cisTarget    INFO     Getting cistromes for CCDC65
# (ctx_internal_ray pid=2120767) 2025-01-28 13:20:02,326 cisTarget    INFO     Annotating motifs for CASZ1 [repeated 2x across cluster]
# (ctx_internal_ray pid=2120779) 2025-01-28 13:20:06,215 cisTarget    INFO     Running cisTarget for CHMP7 which has 12 regions
# (ctx_internal_ray pid=2120778) 2025-01-28 13:20:08,752 cisTarget    INFO     Getting cistromes for CBX5 [repeated 2x across cluster]
# (ctx_internal_ray pid=2120777) 2025-01-28 13:20:05,268 cisTarget    INFO     Annotating motifs for CDC42EP1
# (ctx_internal_ray pid=2120778) 2025-01-28 13:20:11,973 cisTarget    INFO     Running cisTarget for CKB which has 7 regions
# (ctx_internal_ray pid=2120771) 2025-01-28 13:20:07,599 cisTarget    INFO     Running cisTarget for CIZ1 which has 50 regions
# (ctx_internal_ray pid=2120775) 2025-01-28 13:20:12,193 cisTarget    INFO     Annotating motifs for CDK3
# (ctx_internal_ray pid=2120767) 2025-01-28 13:20:14,492 cisTarget    INFO     Getting cistromes for CASZ1
# (ctx_internal_ray pid=2120773) 2025-01-28 13:20:15,830 cisTarget    INFO     Getting cistromes for CCDC12
# (ctx_internal_ray pid=2120767) 2025-01-28 13:20:17,461 cisTarget    INFO     Running cisTarget for CLDN10-AS1 which has 8 regions
# (ctx_internal_ray pid=2120766) 2025-01-28 13:20:15,711 cisTarget    INFO     Annotating motifs for CDHR5 [repeated 3x across cluster]
# (ctx_internal_ray pid=2120777) 2025-01-28 13:20:16,688 cisTarget    INFO     Getting cistromes for CDC42EP1
# (ctx_internal_ray pid=2120777) 2025-01-28 13:20:18,327 cisTarget    INFO     Running cisTarget for CLK3 which has 9 regions [repeated 2x across cluster]
# (ctx_internal_ray pid=2120765) 2025-01-28 13:20:23,394 cisTarget    INFO     Annotating motifs for CCDC9B [repeated 4x across cluster]
# (ctx_internal_ray pid=2120781) 2025-01-28 13:20:24,828 cisTarget    INFO     Getting cistromes for CDCP1
# (ctx_internal_ray pid=2120780) 2025-01-28 13:20:29,036 cisTarget    INFO     Annotating motifs for CEBPG
# (ctx_internal_ray pid=2120774) 2025-01-28 13:20:30,535 cisTarget    INFO     Getting cistromes for CDK5RAP3 [repeated 4x across cluster]
# (ctx_internal_ray pid=2120776) 2025-01-28 13:20:33,604 cisTarget    INFO     Annotating motifs for CDH6
# (ctx_internal_ray pid=2120769) 2025-01-28 13:20:34,358 cisTarget    INFO     Getting cistromes for CGNL1 [repeated 3x across cluster]
# (ctx_internal_ray pid=2120780) 2025-01-28 13:20:38,175 cisTarget    INFO     Getting cistromes for CEBPG
# (ctx_internal_ray pid=2120762) 2025-01-28 13:20:37,617 cisTarget    INFO     Annotating motifs for CHID1 [repeated 3x across cluster]
# (ctx_internal_ray pid=2120770) 2025-01-28 13:20:42,953 cisTarget    INFO     Getting cistromes for CDC34 [repeated 2x across cluster]
# (ctx_internal_ray pid=2120768) 2025-01-28 13:20:50,865 cisTarget    INFO     Annotating motifs for CHAF1A
# (ctx_internal_ray pid=2120762) 2025-01-28 13:20:43,786 cisTarget    INFO     Getting cistromes for CHID1 [repeated 2x across cluster]
# (ctx_internal_ray pid=2120771) 2025-01-28 13:20:52,064 cisTarget    INFO     Annotating motifs for CIZ1
# (ctx_internal_ray pid=2120768) 2025-01-28 13:20:56,527 cisTarget    INFO     Getting cistromes for CHAF1A
# (ctx_internal_ray pid=2120778) 2025-01-28 13:20:56,984 cisTarget    INFO     Annotating motifs for CKB
# (ctx_internal_ray pid=2120771) 2025-01-28 13:20:58,191 cisTarget    INFO     Getting cistromes for CIZ1
# (ctx_internal_ray pid=2120779) 2025-01-28 13:20:54,147 cisTarget    INFO     Annotating motifs for CHMP7
# (ctx_internal_ray pid=2120773) 2025-01-28 13:20:58,798 cisTarget    INFO     Annotating motifs for CLEC16A
# (ctx_internal_ray pid=2120778) 2025-01-28 13:21:02,178 cisTarget    INFO     Getting cistromes for CKB
# (ctx_internal_ray pid=2120767) 2025-01-28 13:21:04,067 cisTarget    INFO     Getting cistromes for CLDN10-AS1 [repeated 2x across cluster]
# (ctx_internal_ray pid=2120777) 2025-01-28 13:20:59,508 cisTarget    INFO     Annotating motifs for CLK3 [repeated 2x across cluster]
# (ctx_internal_ray pid=2120777) 2025-01-28 13:21:05,099 cisTarget    INFO     Getting cistromes for CLK3 [repeated 2x across cluster]
# 2025-01-28 13:21:09,177 cisTarget    INFO     Done!
# 100
# reading database
# 2025-01-28 13:21:09,270 cisTarget    INFO     Reading cisTarget database
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[31], line 3
#       1 import ray
#       2 ray.shutdown()
# ----> 3 read_dictionary_in_chunks(region_sets,100,db =db)
#
# Cell In[29], line 8, in read_dictionary_in_chunks(dictionary, chunk_size, db, specie)
#       6 chunk = {key: dictionary[key] for key in keys[i:i+chunk_size]}
#       7 print("reading database")
# ----> 8 ctx_db = cisTargetDatabase(db, chunk)
#       9 print("cistarget")
#      10 cistarget_dict = run_cistarget(ctx_db = ctx_db,
#      11                        region_sets = chunk,
#      12                        specie = specie,
#    (...)
#      18                        n_cpu = 20,
#      19                        _temp_dir='/oscar/data/rsingh47/tpham43/')
#
# File /oscar/data/koconno5/tpham43/env_scenicplus/lib64/python3.9/site-packages/pycistarget/motif_enrichment_cistarget.py:67, in cisTargetDatabase.__init__(self, fname, region_sets, name, fraction_overlap)
#      48 def __init__(self,
#      49             fname: str,
#      50             region_sets: Union[Dict[str, pr.PyRanges], pr.PyRanges] = None,
#      51             name: str = None,
#      52             fraction_overlap: float = 0.4):
#      53     """
#      54     Initialize cisTargetDatabase
#      55
#    (...)
#      65         Minimal overlap between query and regions in the database for the mapping.
#      66     """
# ---> 67     self.regions_to_db, self.db_rankings, self.total_regions = self.load_db(fname,
#      68                                                       region_sets,
#      69                                                       name,
#      70                                                       fraction_overlap)
#
# File /oscar/data/koconno5/tpham43/env_scenicplus/lib64/python3.9/site-packages/pycistarget/motif_enrichment_cistarget.py:119, in cisTargetDatabase.load_db(self, fname, region_sets, name, fraction_overlap)
#     117 if region_sets is not None:
#     118     if type(region_sets) == dict:
# --> 119         target_to_db_dict = {x: target_to_query(region_sets[x], list(db_regions), fraction_overlap = fraction_overlap) for x in region_sets.keys()}
#     120         target_regions_in_db = list(set(sum([target_to_db_dict[x]['Query'].tolist() for x in target_to_db_dict.keys()],[])))
#     121     elif type(region_sets) == pr.PyRanges:
#
# File /oscar/data/koconno5/tpham43/env_scenicplus/lib64/python3.9/site-packages/pycistarget/motif_enrichment_cistarget.py:119, in <dictcomp>(.0)
#     117 if region_sets is not None:
#     118     if type(region_sets) == dict:
# --> 119         target_to_db_dict = {x: target_to_query(region_sets[x], list(db_regions), fraction_overlap = fraction_overlap) for x in region_sets.keys()}
#     120         target_regions_in_db = list(set(sum([target_to_db_dict[x]['Query'].tolist() for x in target_to_db_dict.keys()],[])))
#     121     elif type(region_sets) == pr.PyRanges:
#
# File /oscar/data/koconno5/tpham43/env_scenicplus/lib64/python3.9/site-packages/pycistarget/utils.py:283, in target_to_query(target, query, fraction_overlap)
#     280     query_pr=query
#     282 join_pr = target_pr.join(query_pr, report_overlap = True)
# --> 283 join_pr.Overlap_query =  join_pr.Overlap/(join_pr.End_b - join_pr.Start_b)
#     284 join_pr.Overlap_target =  join_pr.Overlap/(join_pr.End - join_pr.Start)
#     285 join_pr = join_pr[(join_pr.Overlap_query > fraction_overlap) | (join_pr.Overlap_target > fraction_overlap)]
#
# File /oscar/data/koconno5/tpham43/env_scenicplus/lib64/python3.9/site-packages/pyranges/pyranges_main.py:265, in PyRanges.__getattr__(self, name)
#     240 """Return column.
#     241
#     242 Parameters
#    (...)
#     260 Name: Start, dtype: int64
#     261 """
#     263 from pyranges.methods.attr import _getattr
# --> 265 return _getattr(self, name)
#
# File /oscar/data/koconno5/tpham43/env_scenicplus/lib64/python3.9/site-packages/pyranges/methods/attr.py:65, in _getattr(self, name)
#      63     return pd.concat([df[name] for df in self.values()])
#      64 else:
# ---> 65     raise AttributeError("PyRanges object has no attribute", name)
#
# AttributeError: ('PyRanges object has no attribute', 'Overlap')

# %%
def read_dictionary_in_chunks(dictionary, chunk_size, db, specie='homo_sapiens', outDir=outDir):
    keys = list(dictionary.keys())
    print(f"Total keys: {len(keys)}")
    
    os.makedirs(outDir, exist_ok=True)  # Ensure output directory exists

    for i in range(0, len(keys), chunk_size):
        print(f"{i}")
        chunk = {key: dictionary[key] for key in keys[i:i + chunk_size]}

        try:
            print("Initializing database...")
            ctx_db = cisTargetDatabase(db, chunk)

            print("Running cisTarget...")
            cistarget_dict = run_cistarget(
                ctx_db=ctx_db,
                region_sets=chunk,
                specie=specie,
                annotation_version='v10nr_clust',
                auc_threshold=0.005,
                nes_threshold=3.0,
                rank_threshold=0.05,
                annotation=['Direct_annot', 'Orthology_annot'],
                n_cpu=18,
                _temp_dir='/users/tpham43/'
            )
            
            print("Processing cisTarget results...")
            filtered_data = {
                key: [TF.split('_')[0] for TF in values.cistromes['Region_set'].keys()]
                for key, values in cistarget_dict.items()
            }

            output_file = os.path.join(outDir, f"TF_gene_OT_{i}.csv")
            print(f"Writing results to {output_file}")
            identify_all_TF_gene_link_candidates(filtered_data).to_csv(output_file)

        except Exception as e:
            print(f"Error processing chunk starting at index {i}: {e}")
            continue

# %%
import ray
ray.shutdown()
read_dictionary_in_chunks(region_sets,100,db =db)
# Out:
# Total keys: 666
# 0
# Initializing database...
# 2025-01-28 13:33:44,379 cisTarget    INFO     Reading cisTarget database
# Running cisTarget...
# (ctx_internal_ray pid=2124962) 2025-01-28 13:39:56,510 cisTarget    INFO     Running cisTarget for AFTPH which has 22 regions
# (ctx_internal_ray pid=2124969) 2025-01-28 13:39:56,467 cisTarget    INFO     Running cisTarget for ADAM15 which has 25 regions
# (ctx_internal_ray pid=2124957) 2025-01-28 13:39:56,608 cisTarget    INFO     Running cisTarget for AHRR which has 9 regions
# (ctx_internal_ray pid=2124960) 2025-01-28 13:41:07,029 cisTarget    INFO     Annotating motifs for AKT2
# (ctx_internal_ray pid=2124965) 2025-01-28 13:39:58,703 cisTarget    INFO     Running cisTarget for ABCA7 which has 16 regions [repeated 15x across cluster]
# (ctx_internal_ray pid=2124960) 2025-01-28 13:41:15,712 cisTarget    INFO     Getting cistromes for AKT2
# (ctx_internal_ray pid=2124959) 2025-01-28 13:41:09,461 cisTarget    INFO     Annotating motifs for ABCC3 [repeated 4x across cluster]
# (ctx_internal_ray pid=2124960) 2025-01-28 13:41:18,334 cisTarget    INFO     Running cisTarget for ANKRD29 which has 14 regions
# (ctx_internal_ray pid=2124963) 2025-01-28 13:41:19,940 cisTarget    INFO     Getting cistromes for ALPK3 [repeated 4x across cluster]
# (ctx_internal_ray pid=2124963) 2025-01-28 13:41:23,375 cisTarget    INFO     Running cisTarget for ANKS3 which has 23 regions [repeated 4x across cluster]
# (ctx_internal_ray pid=2124965) 2025-01-28 13:41:47,068 cisTarget    INFO     Annotating motifs for ABCA7
# (ctx_internal_ray pid=2124957) 2025-01-28 13:41:49,137 cisTarget    INFO     Annotating motifs for AHRR
# (ctx_internal_ray pid=2124957) 2025-01-28 13:41:55,988 cisTarget    INFO     Getting cistromes for AHRR
# (ctx_internal_ray pid=2124964) 2025-01-28 13:41:49,205 cisTarget    INFO     Annotating motifs for ACOT9
# (ctx_internal_ray pid=2124964) 2025-01-28 13:41:56,483 cisTarget    INFO     Getting cistromes for ACOT9
# (ctx_internal_ray pid=2124957) 2025-01-28 13:41:56,657 cisTarget    INFO     Running cisTarget for ANPEP which has 8 regions
# (ctx_internal_ray pid=2124964) 2025-01-28 13:41:57,512 cisTarget    INFO     Running cisTarget for ANTXR1 which has 8 regions
# (ctx_internal_ray pid=2124969) 2025-01-28 13:42:02,278 cisTarget    INFO     Annotating motifs for ANKRD40
# (ctx_internal_ray pid=2124965) 2025-01-28 13:42:06,719 cisTarget    INFO     Getting cistromes for ABCA7
# (ctx_internal_ray pid=2124962) 2025-01-28 13:42:07,058 cisTarget    INFO     Annotating motifs for AFTPH
# (ctx_internal_ray pid=2124965) 2025-01-28 13:42:07,864 cisTarget    INFO     Running cisTarget for AP1S3 which has 9 regions
# (ctx_internal_ray pid=2124967) 2025-01-28 13:42:05,629 cisTarget    INFO     Annotating motifs for ANKRD13A
# (ctx_internal_ray pid=2124955) 2025-01-28 13:42:09,700 cisTarget    INFO     Annotating motifs for ANKRD33B
# (ctx_internal_ray pid=2124969) 2025-01-28 13:42:12,280 cisTarget    INFO     Getting cistromes for ANKRD40
# (ctx_internal_ray pid=2124969) 2025-01-28 13:42:14,624 cisTarget    INFO     Running cisTarget for AP3S2 which has 9 regions
# (ctx_internal_ray pid=2124959) 2025-01-28 13:42:14,825 cisTarget    INFO     Annotating motifs for ANKRD46 [repeated 2x across cluster]
# (ctx_internal_ray pid=2124967) 2025-01-28 13:42:16,669 cisTarget    INFO     Getting cistromes for ANKRD13A
# (ctx_internal_ray pid=2124962) 2025-01-28 13:42:18,123 cisTarget    INFO     Getting cistromes for AFTPH
# (ctx_internal_ray pid=2124967) 2025-01-28 13:42:20,427 cisTarget    INFO     Running cisTarget for APBB1 which has 21 regions
# (ctx_internal_ray pid=2124956) 2025-01-28 13:42:18,090 cisTarget    INFO     Annotating motifs for ALS2CL [repeated 2x across cluster]
# (ctx_internal_ray pid=2124962) 2025-01-28 13:42:20,833 cisTarget    INFO     Running cisTarget for APCDD1L which has 12 regions
# (ctx_internal_ray pid=2124955) 2025-01-28 13:42:20,507 cisTarget    INFO     Getting cistromes for ANKRD33B
# (ctx_internal_ray pid=2124959) 2025-01-28 13:42:24,806 cisTarget    INFO     Getting cistromes for ANKRD46
# (ctx_internal_ray pid=2124972) 2025-01-28 13:42:23,986 cisTarget    INFO     Annotating motifs for ALKBH4
# (ctx_internal_ray pid=2124955) 2025-01-28 13:42:23,630 cisTarget    INFO     Running cisTarget for APOL2 which has 43 regions
# (ctx_internal_ray pid=2124968) 2025-01-28 13:42:27,855 cisTarget    INFO     Annotating motifs for ACO2
# (ctx_internal_ray pid=2124970) 2025-01-28 13:42:28,612 cisTarget    INFO     Running cisTarget for APOL3 which has 4 regions
# (ctx_internal_ray pid=2124971) 2025-01-28 13:42:27,877 cisTarget    INFO     Getting cistromes for ADD1 [repeated 3x across cluster]
# (ctx_internal_ray pid=2124958) 2025-01-28 13:42:33,318 cisTarget    INFO     Annotating motifs for ACTN1 [repeated 2x across cluster]
# (ctx_internal_ray pid=2124971) 2025-01-28 13:42:32,427 cisTarget    INFO     Running cisTarget for ARHGAP29 which has 30 regions [repeated 3x across cluster]
# (ctx_internal_ray pid=2124972) 2025-01-28 13:42:33,369 cisTarget    INFO     Getting cistromes for ALKBH4
# (ctx_internal_ray pid=2124968) 2025-01-28 13:42:37,279 cisTarget    INFO     Getting cistromes for ACO2
# (ctx_internal_ray pid=2124966) 2025-01-28 13:42:40,087 cisTarget    INFO     Annotating motifs for AGPAT2 [repeated 2x across cluster]
# (ctx_internal_ray pid=2124972) 2025-01-28 13:42:35,919 cisTarget    INFO     Running cisTarget for ARHGAP32 which has 22 regions
# (ctx_internal_ray pid=2124968) 2025-01-28 13:42:40,661 cisTarget    INFO     Running cisTarget for ARHGAP45 which has 65 regions
# (ctx_internal_ray pid=2124961) 2025-01-28 13:42:42,420 cisTarget    INFO     Getting cistromes for AGAP1
# (ctx_internal_ray pid=2124960) 2025-01-28 13:42:44,563 cisTarget    INFO     Getting cistromes for ANKRD29
# (ctx_internal_ray pid=2124957) 2025-01-28 13:42:44,968 cisTarget    INFO     Annotating motifs for ANPEP
# (ctx_internal_ray pid=2124961) 2025-01-28 13:42:45,023 cisTarget    INFO     Running cisTarget for ARHGEF10L which has 25 regions
# (ctx_internal_ray pid=2124960) 2025-01-28 13:42:48,156 cisTarget    INFO     Running cisTarget for ARHGEF17 which has 10 regions
# (ctx_internal_ray pid=2124958) 2025-01-28 13:42:46,814 cisTarget    INFO     Getting cistromes for ACTN1
# (ctx_internal_ray pid=2124966) 2025-01-28 13:42:53,892 cisTarget    INFO     Getting cistromes for AGPAT2
# (ctx_internal_ray pid=2124958) 2025-01-28 13:42:51,195 cisTarget    INFO     Running cisTarget for ARHGEF40 which has 15 regions
# (ctx_internal_ray pid=2124957) 2025-01-28 13:42:57,772 cisTarget    INFO     Getting cistromes for ANPEP
# (ctx_internal_ray pid=2124966) 2025-01-28 13:42:59,228 cisTarget    INFO     Running cisTarget for ARID3B which has 12 regions
# (ctx_internal_ray pid=2124964) 2025-01-28 13:43:25,830 cisTarget    INFO     Annotating motifs for ANTXR1
# (ctx_internal_ray pid=2124957) 2025-01-28 13:43:01,161 cisTarget    INFO     Running cisTarget for ARID4B which has 16 regions
# (ctx_internal_ray pid=2124969) 2025-01-28 13:43:32,637 cisTarget    INFO     Annotating motifs for AP3S2 [repeated 2x across cluster]
# (ctx_internal_ray pid=2124964) 2025-01-28 13:43:34,790 cisTarget    INFO     Getting cistromes for ANTXR1
# (ctx_internal_ray pid=2124964) 2025-01-28 13:43:36,419 cisTarget    INFO     Running cisTarget for ARMT1 which has 13 regions
# (ctx_internal_ray pid=2124956) 2025-01-28 13:43:35,936 cisTarget    INFO     Annotating motifs for ARAP3
# (ctx_internal_ray pid=2124969) 2025-01-28 13:43:40,807 cisTarget    INFO     Getting cistromes for AP3S2 [repeated 2x across cluster]
# (ctx_internal_ray pid=2124963) 2025-01-28 13:43:40,870 cisTarget    INFO     Running cisTarget for ARSA which has 38 regions
# (ctx_internal_ray pid=2124965) 2025-01-28 13:43:41,642 cisTarget    INFO     Annotating motifs for AP1S3
# (ctx_internal_ray pid=2124969) 2025-01-28 13:43:41,734 cisTarget    INFO     Running cisTarget for ASAP2 which has 10 regions
# (ctx_internal_ray pid=2124956) 2025-01-28 13:43:43,437 cisTarget    INFO     Getting cistromes for ARAP3
# (ctx_internal_ray pid=2124955) 2025-01-28 13:43:53,686 cisTarget    INFO     Annotating motifs for APOL2
# (ctx_internal_ray pid=2124956) 2025-01-28 13:43:44,119 cisTarget    INFO     Running cisTarget for ASB13 which has 16 regions
# (ctx_internal_ray pid=2124958) 2025-01-28 13:43:56,912 cisTarget    INFO     Annotating motifs for ARHGEF40
# (ctx_internal_ray pid=2124965) 2025-01-28 13:43:59,429 cisTarget    INFO     Getting cistromes for AP1S3
# (ctx_internal_ray pid=2124955) 2025-01-28 13:43:59,688 cisTarget    INFO     Running cisTarget for ASB16-AS1 which has 7 regions
# (ctx_internal_ray pid=2124970) 2025-01-28 13:44:02,547 cisTarget    INFO     Annotating motifs for APOL3 [repeated 3x across cluster]
# (ctx_internal_ray pid=2124958) 2025-01-28 13:44:04,801 cisTarget    INFO     Getting cistromes for ARHGEF40 [repeated 2x across cluster]
# (ctx_internal_ray pid=2124965) 2025-01-28 13:43:59,966 cisTarget    INFO     Running cisTarget for ASS1 which has 42 regions
# (ctx_internal_ray pid=2124958) 2025-01-28 13:44:05,962 cisTarget    INFO     Running cisTarget for ATP11A which has 13 regions
# (ctx_internal_ray pid=2124972) 2025-01-28 13:44:06,741 cisTarget    INFO     Annotating motifs for ARHGAP32 [repeated 2x across cluster]
# (ctx_internal_ray pid=2124970) 2025-01-28 13:44:09,861 cisTarget    INFO     Getting cistromes for APOL3 [repeated 3x across cluster]
# (ctx_internal_ray pid=2124970) 2025-01-28 13:44:11,083 cisTarget    INFO     Running cisTarget for AVIL which has 9 regions
# (ctx_internal_ray pid=2124966) 2025-01-28 13:44:08,454 cisTarget    INFO     Running cisTarget for ATP6V0D1 which has 20 regions [repeated 2x across cluster]
# (ctx_internal_ray pid=2124963) 2025-01-28 13:44:11,685 cisTarget    INFO     Annotating motifs for ARSA
# (ctx_internal_ray pid=2124962) 2025-01-28 13:44:13,549 cisTarget    INFO     Annotating motifs for APCDD1L
# (ctx_internal_ray pid=2124959) 2025-01-28 13:44:14,231 cisTarget    INFO     Annotating motifs for ARHGAP21
# (ctx_internal_ray pid=2124972) 2025-01-28 13:44:16,228 cisTarget    INFO     Getting cistromes for ARHGAP32 [repeated 2x across cluster]
# (ctx_internal_ray pid=2124967) 2025-01-28 13:44:17,594 cisTarget    INFO     Running cisTarget for B4GALT7 which has 9 regions
# (ctx_internal_ray pid=2124963) 2025-01-28 13:44:23,029 cisTarget    INFO     Getting cistromes for ARSA
# (ctx_internal_ray pid=2124972) 2025-01-28 13:44:19,148 cisTarget    INFO     Running cisTarget for BAG3 which has 16 regions
# (ctx_internal_ray pid=2124968) 2025-01-28 13:44:24,529 cisTarget    INFO     Annotating motifs for ARHGAP45
# (ctx_internal_ray pid=2124962) 2025-01-28 13:44:24,948 cisTarget    INFO     Getting cistromes for APCDD1L
# (ctx_internal_ray pid=2124963) 2025-01-28 13:44:24,973 cisTarget    INFO     Running cisTarget for BBS12 which has 11 regions
# (ctx_internal_ray pid=2124971) 2025-01-28 13:44:26,065 cisTarget    INFO     Annotating motifs for ARHGAP29
# (ctx_internal_ray pid=2124968) 2025-01-28 13:44:37,913 cisTarget    INFO     Getting cistromes for ARHGAP45 [repeated 2x across cluster]
# (ctx_internal_ray pid=2124962) 2025-01-28 13:44:29,041 cisTarget    INFO     Running cisTarget for BCL9L which has 63 regions [repeated 2x across cluster]
# (ctx_internal_ray pid=2124961) 2025-01-28 13:44:45,577 cisTarget    INFO     Annotating motifs for ARHGEF10L
# (ctx_internal_ray pid=2124971) 2025-01-28 13:44:39,349 cisTarget    INFO     Getting cistromes for ARHGAP29
# (ctx_internal_ray pid=2124971) 2025-01-28 13:44:42,474 cisTarget    INFO     Running cisTarget for BHMT2 which has 9 regions [repeated 2x across cluster]
# (ctx_internal_ray pid=2124961) 2025-01-28 13:44:58,860 cisTarget    INFO     Getting cistromes for ARHGEF10L
# (ctx_internal_ray pid=2124960) 2025-01-28 13:44:59,043 cisTarget    INFO     Annotating motifs for ARHGEF17
# (ctx_internal_ray pid=2124961) 2025-01-28 13:45:00,816 cisTarget    INFO     Running cisTarget for BOD1 which has 12 regions
# (ctx_internal_ray pid=2124960) 2025-01-28 13:45:08,101 cisTarget    INFO     Getting cistromes for ARHGEF17
# (ctx_internal_ray pid=2124955) 2025-01-28 13:45:08,606 cisTarget    INFO     Annotating motifs for ASB16-AS1
# (ctx_internal_ray pid=2124960) 2025-01-28 13:45:10,571 cisTarget    INFO     Running cisTarget for BTBD6 which has 6 regions
# (ctx_internal_ray pid=2124955) 2025-01-28 13:45:17,295 cisTarget    INFO     Getting cistromes for ASB16-AS1
# (ctx_internal_ray pid=2124965) 2025-01-28 13:45:12,049 cisTarget    INFO     Annotating motifs for ASS1 [repeated 2x across cluster]
# (ctx_internal_ray pid=2124955) 2025-01-28 13:45:18,478 cisTarget    INFO     Running cisTarget for BTBD9 which has 8 regions
# (ctx_internal_ray pid=2124970) 2025-01-28 13:45:25,675 cisTarget    INFO     Annotating motifs for AVIL
# (ctx_internal_ray pid=2124956) 2025-01-28 13:45:26,652 cisTarget    INFO     Annotating motifs for ASB13
# (ctx_internal_ray pid=2124967) 2025-01-28 13:45:31,745 cisTarget    INFO     Annotating motifs for B4GALT7
# (ctx_internal_ray pid=2124970) 2025-01-28 13:45:34,103 cisTarget    INFO     Getting cistromes for AVIL
# (ctx_internal_ray pid=2124969) 2025-01-28 13:45:35,059 cisTarget    INFO     Getting cistromes for ASAP2
# (ctx_internal_ray pid=2124970) 2025-01-28 13:45:35,560 cisTarget    INFO     Running cisTarget for BTN3A1 which has 16 regions
# (ctx_internal_ray pid=2124959) 2025-01-28 13:45:36,827 cisTarget    INFO     Annotating motifs for BCL2L11
# (ctx_internal_ray pid=2124967) 2025-01-28 13:45:41,752 cisTarget    INFO     Getting cistromes for B4GALT7 [repeated 3x across cluster]
# (ctx_internal_ray pid=2124969) 2025-01-28 13:45:37,660 cisTarget    INFO     Running cisTarget for C2orf42 which has 14 regions [repeated 3x across cluster]
# (ctx_internal_ray pid=2124963) 2025-01-28 13:45:36,866 cisTarget    INFO     Annotating motifs for BBS12
# (ctx_internal_ray pid=2124968) 2025-01-28 13:45:46,846 cisTarget    INFO     Annotating motifs for BDH2
# (ctx_internal_ray pid=2124967) 2025-01-28 13:45:43,446 cisTarget    INFO     Running cisTarget for C5orf15 which has 19 regions
# (ctx_internal_ray pid=2124963) 2025-01-28 13:45:47,012 cisTarget    INFO     Getting cistromes for BBS12
# (ctx_internal_ray pid=2124959) 2025-01-28 13:45:48,415 cisTarget    INFO     Running cisTarget for C9orf106 which has 10 regions
# (ctx_internal_ray pid=2124964) 2025-01-28 13:45:51,394 cisTarget    INFO     Annotating motifs for ARMT1
# (ctx_internal_ray pid=2124968) 2025-01-28 13:45:56,728 cisTarget    INFO     Getting cistromes for BDH2 [repeated 2x across cluster]
# (ctx_internal_ray pid=2124963) 2025-01-28 13:45:49,167 cisTarget    INFO     Running cisTarget for CA12 which has 9 regions
# (ctx_internal_ray pid=2124961) 2025-01-28 13:45:59,167 cisTarget    INFO     Annotating motifs for BOD1
# (ctx_internal_ray pid=2124968) 2025-01-28 13:45:59,735 cisTarget    INFO     Running cisTarget for CACNA1H which has 38 regions
# (ctx_internal_ray pid=2124964) 2025-01-28 13:46:01,194 cisTarget    INFO     Getting cistromes for ARMT1
# (ctx_internal_ray pid=2124960) 2025-01-28 13:46:08,030 cisTarget    INFO     Getting cistromes for BTBD6
# (ctx_internal_ray pid=2124960) 2025-01-28 13:45:59,556 cisTarget    INFO     Annotating motifs for BTBD6
# (ctx_internal_ray pid=2124964) 2025-01-28 13:46:03,629 cisTarget    INFO     Running cisTarget for CACNA2D3 which has 7 regions
# (ctx_internal_ray pid=2124966) 2025-01-28 13:46:09,134 cisTarget    INFO     Annotating motifs for ATP6V0D1
# (ctx_internal_ray pid=2124960) 2025-01-28 13:46:10,096 cisTarget    INFO     Running cisTarget for CAHM which has 19 regions
# (ctx_internal_ray pid=2124961) 2025-01-28 13:46:11,318 cisTarget    INFO     Running cisTarget for CAMKK1 which has 11 regions
# (ctx_internal_ray pid=2124961) 2025-01-28 13:46:08,025 cisTarget    INFO     Getting cistromes for BOD1
# (ctx_internal_ray pid=2124958) 2025-01-28 13:46:19,083 cisTarget    INFO     Annotating motifs for ATP11A
# (ctx_internal_ray pid=2124957) 2025-01-28 13:46:21,886 cisTarget    INFO     Annotating motifs for ATP5F1B
# (ctx_internal_ray pid=2124958) 2025-01-28 13:46:25,540 cisTarget    INFO     Getting cistromes for ATP11A
# (ctx_internal_ray pid=2124958) 2025-01-28 13:46:26,460 cisTarget    INFO     Running cisTarget for CASR which has 6 regions
# (ctx_internal_ray pid=2124970) 2025-01-28 13:46:25,619 cisTarget    INFO     Annotating motifs for BTN3A1 [repeated 2x across cluster]
# (ctx_internal_ray pid=2124957) 2025-01-28 13:46:30,018 cisTarget    INFO     Running cisTarget for CASZ1 which has 10 regions
# (ctx_internal_ray pid=2124956) 2025-01-28 13:46:32,120 cisTarget    INFO     Getting cistromes for C1QTNF7 [repeated 2x across cluster]
# (ctx_internal_ray pid=2124962) 2025-01-28 13:46:32,999 cisTarget    INFO     Annotating motifs for BCL9L
# (ctx_internal_ray pid=2124971) 2025-01-28 13:46:35,140 cisTarget    INFO     Annotating motifs for BHMT2
# (ctx_internal_ray pid=2124970) 2025-01-28 13:46:34,275 cisTarget    INFO     Running cisTarget for CCAR2 which has 20 regions [repeated 2x across cluster]
# (ctx_internal_ray pid=2124966) 2025-01-28 13:46:36,633 cisTarget    INFO     Getting cistromes for ATP6V0D1 [repeated 2x across cluster]
# (ctx_internal_ray pid=2124964) 2025-01-28 13:46:38,716 cisTarget    INFO     Annotating motifs for CACNA2D3 [repeated 2x across cluster]
# (ctx_internal_ray pid=2124966) 2025-01-28 13:46:43,328 cisTarget    INFO     Running cisTarget for CCDC12 which has 69 regions
# (ctx_internal_ray pid=2124971) 2025-01-28 13:46:44,742 cisTarget    INFO     Running cisTarget for CCDC65 which has 24 regions
# (ctx_internal_ray pid=2124971) 2025-01-28 13:46:43,397 cisTarget    INFO     Getting cistromes for BHMT2
# (ctx_internal_ray pid=2124964) 2025-01-28 13:46:47,578 cisTarget    INFO     Getting cistromes for CACNA2D3
# (ctx_internal_ray pid=2124964) 2025-01-28 13:46:48,627 cisTarget    INFO     Running cisTarget for CCDC82 which has 33 regions
# (ctx_internal_ray pid=2124972) 2025-01-28 13:46:55,904 cisTarget    INFO     Running cisTarget for CCDC9B which has 26 regions
# (ctx_internal_ray pid=2124972) 2025-01-28 13:46:50,516 cisTarget    INFO     Getting cistromes for BAG3
# (ctx_internal_ray pid=2124961) 2025-01-28 13:46:56,177 cisTarget    INFO     Annotating motifs for CAMKK1
# (ctx_internal_ray pid=2124962) 2025-01-28 13:46:58,752 cisTarget    INFO     Getting cistromes for BCL9L
# (ctx_internal_ray pid=2124962) 2025-01-28 13:47:02,296 cisTarget    INFO     Running cisTarget for CCNG2 which has 25 regions
# (ctx_internal_ray pid=2124955) 2025-01-28 13:47:00,232 cisTarget    INFO     Annotating motifs for BTBD9
# (ctx_internal_ray pid=2124961) 2025-01-28 13:47:05,805 cisTarget    INFO     Getting cistromes for CAMKK1
# (ctx_internal_ray pid=2124961) 2025-01-28 13:47:07,758 cisTarget    INFO     Running cisTarget for CD59 which has 16 regions
# (ctx_internal_ray pid=2124955) 2025-01-28 13:47:08,978 cisTarget    INFO     Getting cistromes for BTBD9
# (ctx_internal_ray pid=2124958) 2025-01-28 13:47:11,952 cisTarget    INFO     Annotating motifs for CASR
# (ctx_internal_ray pid=2124958) 2025-01-28 13:47:24,902 cisTarget    INFO     Getting cistromes for CASR
# (ctx_internal_ray pid=2124955) 2025-01-28 13:47:11,403 cisTarget    INFO     Running cisTarget for CDC34 which has 20 regions
# (ctx_internal_ray pid=2124958) 2025-01-28 13:47:26,682 cisTarget    INFO     Running cisTarget for CDC42EP1 which has 22 regions
# (ctx_internal_ray pid=2124963) 2025-01-28 13:47:26,781 cisTarget    INFO     Annotating motifs for CA12
# (ctx_internal_ray pid=2124957) 2025-01-28 13:47:32,472 cisTarget    INFO     Annotating motifs for CASZ1 [repeated 4x across cluster]
# (ctx_internal_ray pid=2124960) 2025-01-28 13:47:35,219 cisTarget    INFO     Annotating motifs for CAHM
# (ctx_internal_ray pid=2124963) 2025-01-28 13:47:35,713 cisTarget    INFO     Getting cistromes for CA12
# (ctx_internal_ray pid=2124963) 2025-01-28 13:47:37,108 cisTarget    INFO     Running cisTarget for CDC5L which has 17 regions
# (ctx_internal_ray pid=2124967) 2025-01-28 13:47:38,144 cisTarget    INFO     Annotating motifs for C5orf15 [repeated 3x across cluster]
# (ctx_internal_ray pid=2124957) 2025-01-28 13:47:40,747 cisTarget    INFO     Getting cistromes for CASZ1 [repeated 3x across cluster]
# (ctx_internal_ray pid=2124969) 2025-01-28 13:47:43,920 cisTarget    INFO     Running cisTarget for CDK3 which has 33 regions [repeated 4x across cluster]
# (ctx_internal_ray pid=2124971) 2025-01-28 13:47:41,998 cisTarget    INFO     Annotating motifs for CCDC65
# (ctx_internal_ray pid=2124960) 2025-01-28 13:47:45,865 cisTarget    INFO     Getting cistromes for CAHM
# (ctx_internal_ray pid=2124969) 2025-01-28 13:47:41,380 cisTarget    INFO     Getting cistromes for C2orf42
# (ctx_internal_ray pid=2124965) 2025-01-28 13:47:46,887 cisTarget    INFO     Getting cistromes for C5
# (ctx_internal_ray pid=2124959) 2025-01-28 13:47:48,019 cisTarget    INFO     Annotating motifs for C9orf106
# (ctx_internal_ray pid=2124965) 2025-01-28 13:47:49,323 cisTarget    INFO     Running cisTarget for CEBPG which has 10 regions
# (ctx_internal_ray pid=2124960) 2025-01-28 13:47:46,938 cisTarget    INFO     Running cisTarget for CDK5RAP3 which has 7 regions
# (ctx_internal_ray pid=2124967) 2025-01-28 13:47:54,158 cisTarget    INFO     Running cisTarget for CGNL1 which has 11 regions
# (ctx_internal_ray pid=2124956) 2025-01-28 13:47:49,662 cisTarget    INFO     Getting cistromes for CBX5 [repeated 2x across cluster]
# (ctx_internal_ray pid=2124971) 2025-01-28 13:47:59,246 cisTarget    INFO     Running cisTarget for CHID1 which has 96 regions [repeated 2x across cluster]
# (ctx_internal_ray pid=2124971) 2025-01-28 13:47:54,471 cisTarget    INFO     Getting cistromes for CCDC65
# (ctx_internal_ray pid=2124972) 2025-01-28 13:48:01,393 cisTarget    INFO     Annotating motifs for CCDC9B
# (ctx_internal_ray pid=2124959) 2025-01-28 13:48:02,004 cisTarget    INFO     Getting cistromes for C9orf106
# (ctx_internal_ray pid=2124959) 2025-01-28 13:48:06,783 cisTarget    INFO     Running cisTarget for CHMP7 which has 12 regions
# (ctx_internal_ray pid=2124966) 2025-01-28 13:48:07,889 cisTarget    INFO     Annotating motifs for CCDC12
# (ctx_internal_ray pid=2124972) 2025-01-28 13:48:13,985 cisTarget    INFO     Getting cistromes for CCDC9B
# (ctx_internal_ray pid=2124966) 2025-01-28 13:48:19,643 cisTarget    INFO     Getting cistromes for CCDC12
# (ctx_internal_ray pid=2124972) 2025-01-28 13:48:19,758 cisTarget    INFO     Running cisTarget for CIZ1 which has 50 regions
# (ctx_internal_ray pid=2124966) 2025-01-28 13:48:21,351 cisTarget    INFO     Running cisTarget for CKB which has 7 regions
# (ctx_internal_ray pid=2124964) 2025-01-28 13:48:36,837 cisTarget    INFO     Annotating motifs for CCDC82
# (ctx_internal_ray pid=2124964) 2025-01-28 13:48:47,272 cisTarget    INFO     Getting cistromes for CCDC82
# (ctx_internal_ray pid=2124962) 2025-01-28 13:48:50,051 cisTarget    INFO     Annotating motifs for CCNG2
# (ctx_internal_ray pid=2124964) 2025-01-28 13:48:51,238 cisTarget    INFO     Running cisTarget for CLDN10-AS1 which has 8 regions
# (ctx_internal_ray pid=2124962) 2025-01-28 13:48:59,428 cisTarget    INFO     Getting cistromes for CCNG2
# (ctx_internal_ray pid=2124961) 2025-01-28 13:49:00,858 cisTarget    INFO     Annotating motifs for CD59
# (ctx_internal_ray pid=2124962) 2025-01-28 13:49:01,941 cisTarget    INFO     Running cisTarget for CLEC16A which has 5 regions
# (ctx_internal_ray pid=2124960) 2025-01-28 13:49:07,609 cisTarget    INFO     Annotating motifs for CDK5RAP3 [repeated 3x across cluster]
# (ctx_internal_ray pid=2124961) 2025-01-28 13:49:11,378 cisTarget    INFO     Getting cistromes for CD59
# (ctx_internal_ray pid=2124969) 2025-01-28 13:49:10,682 cisTarget    INFO     Annotating motifs for CDK3 [repeated 3x across cluster]
# (ctx_internal_ray pid=2124961) 2025-01-28 13:49:13,078 cisTarget    INFO     Running cisTarget for CLK3 which has 9 regions
# (ctx_internal_ray pid=2124968) 2025-01-28 13:49:17,723 cisTarget    INFO     Getting cistromes for CDH6 [repeated 5x across cluster]
# (ctx_internal_ray pid=2124958) 2025-01-28 13:49:18,438 cisTarget    INFO     Annotating motifs for CDC42EP1 [repeated 2x across cluster]
# (ctx_internal_ray pid=2124967) 2025-01-28 13:49:19,856 cisTarget    INFO     Getting cistromes for CGNL1 [repeated 2x across cluster]
# (ctx_internal_ray pid=2124970) 2025-01-28 13:49:23,217 cisTarget    INFO     Annotating motifs for CDCP1 [repeated 3x across cluster]
# (ctx_internal_ray pid=2124965) 2025-01-28 13:49:30,701 cisTarget    INFO     Annotating motifs for CEBPG
# (ctx_internal_ray pid=2124972) 2025-01-28 13:49:24,675 cisTarget    INFO     Getting cistromes for CIZ1 [repeated 2x across cluster]
# (ctx_internal_ray pid=2124963) 2025-01-28 13:49:25,513 cisTarget    INFO     Annotating motifs for CDC5L
# (ctx_internal_ray pid=2124964) 2025-01-28 13:49:31,659 cisTarget    INFO     Annotating motifs for CLDN10-AS1
# (ctx_internal_ray pid=2124966) 2025-01-28 13:49:33,507 cisTarget    INFO     Annotating motifs for CKB
# (ctx_internal_ray pid=2124965) 2025-01-28 13:49:35,972 cisTarget    INFO     Getting cistromes for CEBPG
# (ctx_internal_ray pid=2124963) 2025-01-28 13:49:32,805 cisTarget    INFO     Getting cistromes for CDC5L [repeated 3x across cluster]
# (ctx_internal_ray pid=2124961) 2025-01-28 13:49:37,007 cisTarget    INFO     Annotating motifs for CLK3 [repeated 3x across cluster]
# (ctx_internal_ray pid=2124966) 2025-01-28 13:49:38,670 cisTarget    INFO     Getting cistromes for CKB
# (ctx_internal_ray pid=2124962) 2025-01-28 13:49:41,260 cisTarget    INFO     Getting cistromes for CLEC16A [repeated 3x across cluster]
# (ctx_internal_ray pid=2124961) 2025-01-28 13:49:42,071 cisTarget    INFO     Getting cistromes for CLK3
# 2025-01-28 13:49:44,375 cisTarget    INFO     Done!
# Processing cisTarget results...
# Writing results to ./results_OT/results/TF_gene/TF_gene_OT_0.csv
# 100
# Initializing database...
# 2025-01-28 13:49:45,765 cisTarget    INFO     Reading cisTarget database
# Error processing chunk starting at index 100: ('PyRanges object has no attribute', 'Overlap')
# 200
# Initializing database...
# 2025-01-28 13:55:28,790 cisTarget    INFO     Reading cisTarget database
# Running cisTarget...
# (ctx_internal_ray pid=2128678) 2025-01-28 14:01:36,141 cisTarget    INFO     Running cisTarget for GGT6 which has 10 regions
# (ctx_internal_ray pid=2128684) 2025-01-28 14:01:36,700 cisTarget    INFO     Running cisTarget for GMFB which has 29 regions
# (ctx_internal_ray pid=2128669) 2025-01-28 14:01:36,940 cisTarget    INFO     Running cisTarget for GHITM which has 16 regions
# (ctx_internal_ray pid=2128682) 2025-01-28 14:02:47,791 cisTarget    INFO     Annotating motifs for GBA2
# (ctx_internal_ray pid=2128667) 2025-01-28 14:01:37,836 cisTarget    INFO     Running cisTarget for GPRC5D-AS1 which has 28 regions [repeated 15x across cluster]
# (ctx_internal_ray pid=2128675) 2025-01-28 14:02:55,743 cisTarget    INFO     Getting cistromes for GPR137B
# (ctx_internal_ray pid=2128679) 2025-01-28 14:02:51,168 cisTarget    INFO     Annotating motifs for GOLGA5 [repeated 3x across cluster]
# (ctx_internal_ray pid=2128675) 2025-01-28 14:02:57,649 cisTarget    INFO     Running cisTarget for GPSM1 which has 17 regions
# (ctx_internal_ray pid=2128679) 2025-01-28 14:03:00,517 cisTarget    INFO     Getting cistromes for GOLGA5 [repeated 3x across cluster]
# (ctx_internal_ray pid=2128673) 2025-01-28 14:03:02,888 cisTarget    INFO     Annotating motifs for GLIS2-AS1
# (ctx_internal_ray pid=2128678) 2025-01-28 14:02:59,938 cisTarget    INFO     Running cisTarget for GRAMD4 which has 57 regions [repeated 2x across cluster]
# (ctx_internal_ray pid=2128673) 2025-01-28 14:03:11,450 cisTarget    INFO     Getting cistromes for GLIS2-AS1
# (ctx_internal_ray pid=2128679) 2025-01-28 14:03:03,666 cisTarget    INFO     Running cisTarget for GRIPAP1 which has 24 regions
# (ctx_internal_ray pid=2128673) 2025-01-28 14:03:13,806 cisTarget    INFO     Running cisTarget for GSTM3 which has 14 regions
# (ctx_internal_ray pid=2128681) 2025-01-28 14:03:18,258 cisTarget    INFO     Annotating motifs for GPD1
# (ctx_internal_ray pid=2128684) 2025-01-28 14:03:20,494 cisTarget    INFO     Annotating motifs for GMFB
# (ctx_internal_ray pid=2128681) 2025-01-28 14:03:26,009 cisTarget    INFO     Getting cistromes for GPD1
# (ctx_internal_ray pid=2128668) 2025-01-28 14:03:19,022 cisTarget    INFO     Annotating motifs for GNG12
# (ctx_internal_ray pid=2128681) 2025-01-28 14:03:26,784 cisTarget    INFO     Running cisTarget for GTPBP2 which has 14 regions
# (ctx_internal_ray pid=2128684) 2025-01-28 14:03:28,829 cisTarget    INFO     Getting cistromes for GMFB
# (ctx_internal_ray pid=2128668) 2025-01-28 14:03:28,886 cisTarget    INFO     Running cisTarget for HAGLR which has 37 regions
# (ctx_internal_ray pid=2128677) 2025-01-28 14:03:40,196 cisTarget    INFO     Annotating motifs for GPAA1
# (ctx_internal_ray pid=2128668) 2025-01-28 14:03:27,695 cisTarget    INFO     Getting cistromes for GNG12
# (ctx_internal_ray pid=2128684) 2025-01-28 14:03:30,508 cisTarget    INFO     Running cisTarget for HDAC3 which has 37 regions
# (ctx_internal_ray pid=2128677) 2025-01-28 14:03:47,763 cisTarget    INFO     Getting cistromes for GPAA1
# (ctx_internal_ray pid=2128677) 2025-01-28 14:03:48,758 cisTarget    INFO     Running cisTarget for HDAC7 which has 6 regions
# (ctx_internal_ray pid=2128675) 2025-01-28 14:03:55,107 cisTarget    INFO     Annotating motifs for GPSM1
# (ctx_internal_ray pid=2128673) 2025-01-28 14:04:00,554 cisTarget    INFO     Annotating motifs for GSTM3
# (ctx_internal_ray pid=2128675) 2025-01-28 14:04:02,030 cisTarget    INFO     Getting cistromes for GPSM1
# (ctx_internal_ray pid=2128675) 2025-01-28 14:04:03,157 cisTarget    INFO     Running cisTarget for HEY2 which has 14 regions
# (ctx_internal_ray pid=2128667) 2025-01-28 14:04:03,823 cisTarget    INFO     Annotating motifs for GPRC5D-AS1
# (ctx_internal_ray pid=2128682) 2025-01-28 14:04:44,646 cisTarget    INFO     Running cisTarget for HS1BP3 which has 6 regions
# (ctx_internal_ray pid=2128675) 2025-01-28 14:04:47,464 cisTarget    INFO     Getting cistromes for HEY2 [repeated 2x across cluster]
# (ctx_internal_ray pid=2128676) 2025-01-28 14:04:48,611 cisTarget    INFO     Annotating motifs for GDF15
# (ctx_internal_ray pid=2128675) 2025-01-28 14:04:51,010 cisTarget    INFO     Running cisTarget for ICA1 which has 22 regions
# (ctx_internal_ray pid=2128674) 2025-01-28 14:04:49,930 cisTarget    INFO     Getting cistromes for GALNT2
# (ctx_internal_ray pid=2128683) 2025-01-28 14:04:57,009 cisTarget    INFO     Getting cistromes for GNB5
# (ctx_internal_ray pid=2128674) 2025-01-28 14:04:52,995 cisTarget    INFO     Running cisTarget for IGFBP4 which has 54 regions
# (ctx_internal_ray pid=2128683) 2025-01-28 14:04:59,352 cisTarget    INFO     Running cisTarget for IGIP which has 20 regions
# (ctx_internal_ray pid=2128676) 2025-01-28 14:05:03,100 cisTarget    INFO     Running cisTarget for IKBKG which has 15 regions
# (ctx_internal_ray pid=2128676) 2025-01-28 14:04:59,719 cisTarget    INFO     Getting cistromes for GDF15
# (ctx_internal_ray pid=2128684) 2025-01-28 14:05:05,421 cisTarget    INFO     Annotating motifs for HIVEP3
# (ctx_internal_ray pid=2128684) 2025-01-28 14:05:14,240 cisTarget    INFO     Getting cistromes for HIVEP3
# (ctx_internal_ray pid=2128673) 2025-01-28 14:05:08,881 cisTarget    INFO     Annotating motifs for HIGD1A
# (ctx_internal_ray pid=2128684) 2025-01-28 14:05:15,694 cisTarget    INFO     Running cisTarget for IL1R2 which has 16 regions
# (ctx_internal_ray pid=2128677) 2025-01-28 14:05:20,911 cisTarget    INFO     Annotating motifs for HOXA-AS2
# (ctx_internal_ray pid=2128673) 2025-01-28 14:05:18,237 cisTarget    INFO     Getting cistromes for HIGD1A
# (ctx_internal_ray pid=2128673) 2025-01-28 14:05:21,710 cisTarget    INFO     Running cisTarget for ILRUN which has 18 regions
# (ctx_internal_ray pid=2128677) 2025-01-28 14:05:29,041 cisTarget    INFO     Getting cistromes for HOXA-AS2
# (ctx_internal_ray pid=2128679) 2025-01-28 14:05:29,481 cisTarget    INFO     Annotating motifs for GRIPAP1
# (ctx_internal_ray pid=2128677) 2025-01-28 14:05:29,969 cisTarget    INFO     Running cisTarget for IMP3 which has 19 regions
# (ctx_internal_ray pid=2128672) 2025-01-28 14:05:36,373 cisTarget    INFO     Annotating motifs for HOXB-AS1 [repeated 2x across cluster]
# (ctx_internal_ray pid=2128681) 2025-01-28 14:05:42,211 cisTarget    INFO     Getting cistromes for HOXA9
# (ctx_internal_ray pid=2128681) 2025-01-28 14:05:42,857 cisTarget    INFO     Running cisTarget for INO80-AS1 which has 12 regions
# (ctx_internal_ray pid=2128667) 2025-01-28 14:05:49,282 cisTarget    INFO     Annotating motifs for HNF1B
# (ctx_internal_ray pid=2128672) 2025-01-28 14:05:44,669 cisTarget    INFO     Getting cistromes for HOXB-AS1
# (ctx_internal_ray pid=2128672) 2025-01-28 14:05:45,674 cisTarget    INFO     Running cisTarget for INO80B which has 40 regions
# (ctx_internal_ray pid=2128679) 2025-01-28 14:05:56,134 cisTarget    INFO     Getting cistromes for GRIPAP1
# (ctx_internal_ray pid=2128667) 2025-01-28 14:05:57,609 cisTarget    INFO     Running cisTarget for INPP5F which has 17 regions
# (ctx_internal_ray pid=2128683) 2025-01-28 14:05:59,631 cisTarget    INFO     Annotating motifs for IGIP
# (ctx_internal_ray pid=2128676) 2025-01-28 14:06:01,374 cisTarget    INFO     Annotating motifs for IKBKG
# (ctx_internal_ray pid=2128667) 2025-01-28 14:05:56,931 cisTarget    INFO     Getting cistromes for HNF1B
# (ctx_internal_ray pid=2128683) 2025-01-28 14:06:08,207 cisTarget    INFO     Getting cistromes for IGIP
# (ctx_internal_ray pid=2128679) 2025-01-28 14:06:00,284 cisTarget    INFO     Running cisTarget for INTS11 which has 8 regions
# (ctx_internal_ray pid=2128676) 2025-01-28 14:06:09,565 cisTarget    INFO     Getting cistromes for IKBKG
# (ctx_internal_ray pid=2128684) 2025-01-28 14:06:09,568 cisTarget    INFO     Annotating motifs for IL1R2
# (ctx_internal_ray pid=2128683) 2025-01-28 14:06:10,107 cisTarget    INFO     Running cisTarget for IQCD which has 19 regions
# (ctx_internal_ray pid=2128676) 2025-01-28 14:06:11,224 cisTarget    INFO     Running cisTarget for IQCN which has 62 regions
# (ctx_internal_ray pid=2128684) 2025-01-28 14:06:16,699 cisTarget    INFO     Getting cistromes for IL1R2
# (ctx_internal_ray pid=2128677) 2025-01-28 14:06:09,866 cisTarget    INFO     Annotating motifs for IMP3
# (ctx_internal_ray pid=2128669) 2025-01-28 14:06:17,598 cisTarget    INFO     Annotating motifs for HOGA1
# (ctx_internal_ray pid=2128684) 2025-01-28 14:06:17,617 cisTarget    INFO     Running cisTarget for IRF1 which has 18 regions
# (ctx_internal_ray pid=2128668) 2025-01-28 14:06:28,469 cisTarget    INFO     Annotating motifs for HLCS
# (ctx_internal_ray pid=2128677) 2025-01-28 14:06:17,953 cisTarget    INFO     Getting cistromes for IMP3
# (ctx_internal_ray pid=2128677) 2025-01-28 14:06:18,657 cisTarget    INFO     Running cisTarget for IRF2BP2 which has 6 regions
# (ctx_internal_ray pid=2128668) 2025-01-28 14:06:35,314 cisTarget    INFO     Getting cistromes for HLCS
# (ctx_internal_ray pid=2128668) 2025-01-28 14:06:36,012 cisTarget    INFO     Running cisTarget for IRF2BPL which has 31 regions
# (ctx_internal_ray pid=2128667) 2025-01-28 14:06:37,593 cisTarget    INFO     Annotating motifs for INPP5F
# (ctx_internal_ray pid=2128678) 2025-01-28 14:06:42,997 cisTarget    INFO     Annotating motifs for HOXB6 [repeated 2x across cluster]
# (ctx_internal_ray pid=2128669) 2025-01-28 14:06:43,928 cisTarget    INFO     Getting cistromes for HOGA1
# (ctx_internal_ray pid=2128680) 2025-01-28 14:06:43,945 cisTarget    INFO     Annotating motifs for HPN
# (ctx_internal_ray pid=2128670) 2025-01-28 14:06:47,171 cisTarget    INFO     Running cisTarget for IRF7 which has 20 regions
# (ctx_internal_ray pid=2128674) 2025-01-28 14:06:49,243 cisTarget    INFO     Annotating motifs for IGFBP4 [repeated 3x across cluster]
# (ctx_internal_ray pid=2128667) 2025-01-28 14:06:46,541 cisTarget    INFO     Getting cistromes for INPP5F [repeated 2x across cluster]
# (ctx_internal_ray pid=2128676) 2025-01-28 14:06:50,771 cisTarget    INFO     Annotating motifs for IQCN
# (ctx_internal_ray pid=2128680) 2025-01-28 14:06:53,462 cisTarget    INFO     Getting cistromes for HPN
# (ctx_internal_ray pid=2128667) 2025-01-28 14:06:47,551 cisTarget    INFO     Running cisTarget for ITIH4 which has 17 regions [repeated 2x across cluster]
# (ctx_internal_ray pid=2128680) 2025-01-28 14:06:55,487 cisTarget    INFO     Running cisTarget for ITPKB which has 12 regions
# (ctx_internal_ray pid=2128671) 2025-01-28 14:06:51,883 cisTarget    INFO     Annotating motifs for HOXC10
# (ctx_internal_ray pid=2128681) 2025-01-28 14:06:55,742 cisTarget    INFO     Getting cistromes for INO80-AS1
# (ctx_internal_ray pid=2128683) 2025-01-28 14:06:55,815 cisTarget    INFO     Annotating motifs for IQCD
# (ctx_internal_ray pid=2128672) 2025-01-28 14:06:57,110 cisTarget    INFO     Running cisTarget for ITPKC which has 25 regions
# (ctx_internal_ray pid=2128681) 2025-01-28 14:06:58,206 cisTarget    INFO     Running cisTarget for JADE1 which has 33 regions
# (ctx_internal_ray pid=2128674) 2025-01-28 14:07:00,914 cisTarget    INFO     Running cisTarget for JADE2 which has 13 regions
# (ctx_internal_ray pid=2128678) 2025-01-28 14:07:00,420 cisTarget    INFO     Getting cistromes for HOXB6 [repeated 3x across cluster]
# (ctx_internal_ray pid=2128676) 2025-01-28 14:07:01,252 cisTarget    INFO     Getting cistromes for IQCN
# (ctx_internal_ray pid=2128682) 2025-01-28 14:07:02,670 cisTarget    INFO     Annotating motifs for HS1BP3
# (ctx_internal_ray pid=2128671) 2025-01-28 14:07:03,328 cisTarget    INFO     Running cisTarget for JUND which has 22 regions
# (ctx_internal_ray pid=2128683) 2025-01-28 14:07:05,592 cisTarget    INFO     Getting cistromes for IQCD
# (ctx_internal_ray pid=2128673) 2025-01-28 14:07:09,253 cisTarget    INFO     Annotating motifs for ILRUN
# (ctx_internal_ray pid=2128676) 2025-01-28 14:07:04,404 cisTarget    INFO     Running cisTarget for KANK2 which has 33 regions [repeated 2x across cluster]
# (ctx_internal_ray pid=2128671) 2025-01-28 14:07:01,425 cisTarget    INFO     Getting cistromes for HOXC10
# (ctx_internal_ray pid=2128682) 2025-01-28 14:07:12,791 cisTarget    INFO     Getting cistromes for HS1BP3
# (ctx_internal_ray pid=2128682) 2025-01-28 14:07:15,819 cisTarget    INFO     Running cisTarget for KATNB1 which has 46 regions [repeated 2x across cluster]
# (ctx_internal_ray pid=2128673) 2025-01-28 14:07:21,287 cisTarget    INFO     Getting cistromes for ILRUN
# (ctx_internal_ray pid=2128675) 2025-01-28 14:07:25,570 cisTarget    INFO     Annotating motifs for ICA1
# (ctx_internal_ray pid=2128673) 2025-01-28 14:07:27,248 cisTarget    INFO     Running cisTarget for KCTD6 which has 20 regions
# (ctx_internal_ray pid=2128679) 2025-01-28 14:07:36,127 cisTarget    INFO     Annotating motifs for INTS11 [repeated 2x across cluster]
# (ctx_internal_ray pid=2128675) 2025-01-28 14:07:36,288 cisTarget    INFO     Getting cistromes for ICA1
# (ctx_internal_ray pid=2128675) 2025-01-28 14:07:41,372 cisTarget    INFO     Running cisTarget for KDM4B which has 11 regions
# (ctx_internal_ray pid=2128684) 2025-01-28 14:07:39,525 cisTarget    INFO     Annotating motifs for IRF1
# (ctx_internal_ray pid=2128677) 2025-01-28 14:07:39,778 cisTarget    INFO     Getting cistromes for IRF2BP2
# (ctx_internal_ray pid=2128679) 2025-01-28 14:07:45,906 cisTarget    INFO     Getting cistromes for INTS11
# (ctx_internal_ray pid=2128679) 2025-01-28 14:07:46,780 cisTarget    INFO     Running cisTarget for KLF2 which has 18 regions [repeated 2x across cluster]
# (ctx_internal_ray pid=2128667) 2025-01-28 14:07:56,350 cisTarget    INFO     Annotating motifs for ITIH4
# (ctx_internal_ray pid=2128684) 2025-01-28 14:07:46,849 cisTarget    INFO     Getting cistromes for IRF1
# (ctx_internal_ray pid=2128684) 2025-01-28 14:07:48,639 cisTarget    INFO     Running cisTarget for KLHL14 which has 4 regions
# (ctx_internal_ray pid=2128680) 2025-01-28 14:08:00,139 cisTarget    INFO     Annotating motifs for ITPKB
# (ctx_internal_ray pid=2128667) 2025-01-28 14:08:03,130 cisTarget    INFO     Getting cistromes for ITIH4
# (ctx_internal_ray pid=2128670) 2025-01-28 14:07:58,067 cisTarget    INFO     Annotating motifs for IRF7
# (ctx_internal_ray pid=2128667) 2025-01-28 14:08:04,220 cisTarget    INFO     Running cisTarget for KPNB1 which has 20 regions
# (ctx_internal_ray pid=2128668) 2025-01-28 14:08:07,486 cisTarget    INFO     Annotating motifs for IRF2BPL
# (ctx_internal_ray pid=2128680) 2025-01-28 14:08:07,989 cisTarget    INFO     Getting cistromes for ITPKB
# (ctx_internal_ray pid=2128670) 2025-01-28 14:08:06,421 cisTarget    INFO     Getting cistromes for IRF7
# (ctx_internal_ray pid=2128680) 2025-01-28 14:08:09,412 cisTarget    INFO     Running cisTarget for KREMEN1 which has 13 regions
# (ctx_internal_ray pid=2128670) 2025-01-28 14:08:10,048 cisTarget    INFO     Running cisTarget for KRT7 which has 18 regions
# (ctx_internal_ray pid=2128668) 2025-01-28 14:08:16,922 cisTarget    INFO     Getting cistromes for IRF2BPL
# (ctx_internal_ray pid=2128668) 2025-01-28 14:08:18,087 cisTarget    INFO     Running cisTarget for LAMA5 which has 19 regions
# (ctx_internal_ray pid=2128675) 2025-01-28 14:08:25,075 cisTarget    INFO     Annotating motifs for KDM4B
# (ctx_internal_ray pid=2128672) 2025-01-28 14:08:27,832 cisTarget    INFO     Annotating motifs for ITPKC
# (ctx_internal_ray pid=2128684) 2025-01-28 14:08:32,018 cisTarget    INFO     Annotating motifs for KLHL14
# (ctx_internal_ray pid=2128675) 2025-01-28 14:08:33,667 cisTarget    INFO     Getting cistromes for KDM4B
# (ctx_internal_ray pid=2128679) 2025-01-28 14:08:34,777 cisTarget    INFO     Annotating motifs for KLF2
# (ctx_internal_ray pid=2128675) 2025-01-28 14:08:34,761 cisTarget    INFO     Running cisTarget for LARGE2 which has 19 regions
# (ctx_internal_ray pid=2128672) 2025-01-28 14:08:37,600 cisTarget    INFO     Getting cistromes for ITPKC
# (ctx_internal_ray pid=2128684) 2025-01-28 14:08:40,148 cisTarget    INFO     Getting cistromes for KLHL14
# (ctx_internal_ray pid=2128672) 2025-01-28 14:08:38,066 cisTarget    INFO     Running cisTarget for LATS2-AS1 which has 11 regions
# (ctx_internal_ray pid=2128684) 2025-01-28 14:08:42,571 cisTarget    INFO     Running cisTarget for LCMT1-AS1 which has 6 regions
# (ctx_internal_ray pid=2128679) 2025-01-28 14:08:44,131 cisTarget    INFO     Getting cistromes for KLF2
# (ctx_internal_ray pid=2128671) 2025-01-28 14:08:46,787 cisTarget    INFO     Annotating motifs for JUND
# (ctx_internal_ray pid=2128671) 2025-01-28 14:08:57,340 cisTarget    INFO     Getting cistromes for JUND
# (ctx_internal_ray pid=2128679) 2025-01-28 14:08:46,938 cisTarget    INFO     Running cisTarget for LCN12 which has 37 regions
# (ctx_internal_ray pid=2128681) 2025-01-28 14:08:57,587 cisTarget    INFO     Annotating motifs for JADE1
# (ctx_internal_ray pid=2128671) 2025-01-28 14:09:00,925 cisTarget    INFO     Running cisTarget for LEMD2 which has 22 regions
# (ctx_internal_ray pid=2128678) 2025-01-28 14:09:04,575 cisTarget    INFO     Annotating motifs for JDP2 [repeated 4x across cluster]
# (ctx_internal_ray pid=2128681) 2025-01-28 14:09:07,039 cisTarget    INFO     Getting cistromes for JADE1
# (ctx_internal_ray pid=2128681) 2025-01-28 14:09:08,048 cisTarget    INFO     Running cisTarget for LGALS2 which has 13 regions
# (ctx_internal_ray pid=2128670) 2025-01-28 14:09:10,460 cisTarget    INFO     Annotating motifs for KRT7 [repeated 2x across cluster]
# (ctx_internal_ray pid=2128669) 2025-01-28 14:09:12,696 cisTarget    INFO     Getting cistromes for ISYNA1 [repeated 3x across cluster]
# (ctx_internal_ray pid=2128667) 2025-01-28 14:09:13,631 cisTarget    INFO     Running cisTarget for LGALS3BP which has 25 regions
# (ctx_internal_ray pid=2128674) 2025-01-28 14:09:13,738 cisTarget    INFO     Running cisTarget for LGR4 which has 20 regions
# (ctx_internal_ray pid=2128669) 2025-01-28 14:09:14,985 cisTarget    INFO     Running cisTarget for LIAS which has 13 regions
# (ctx_internal_ray pid=2128678) 2025-01-28 14:09:16,425 cisTarget    INFO     Running cisTarget for LIF which has 10 regions
# (ctx_internal_ray pid=2128683) 2025-01-28 14:09:11,831 cisTarget    INFO     Annotating motifs for KAT2A [repeated 2x across cluster]
# (ctx_internal_ray pid=2128678) 2025-01-28 14:09:15,386 cisTarget    INFO     Getting cistromes for JDP2
# (ctx_internal_ray pid=2128670) 2025-01-28 14:09:22,007 cisTarget    INFO     Getting cistromes for KRT7
# (ctx_internal_ray pid=2128676) 2025-01-28 14:09:20,474 cisTarget    INFO     Annotating motifs for KANK2
# (ctx_internal_ray pid=2128668) 2025-01-28 14:09:22,196 cisTarget    INFO     Annotating motifs for LAMA5
# (ctx_internal_ray pid=2128682) 2025-01-28 14:09:24,322 cisTarget    INFO     Running cisTarget for LIFR-AS1 which has 8 regions
# (ctx_internal_ray pid=2128680) 2025-01-28 14:09:23,214 cisTarget    INFO     Getting cistromes for KREMEN1 [repeated 3x across cluster]
# (ctx_internal_ray pid=2128677) 2025-01-28 14:09:32,220 cisTarget    INFO     Annotating motifs for KIFC3
# (ctx_internal_ray pid=2128683) 2025-01-28 14:09:25,620 cisTarget    INFO     Running cisTarget for LIMCH1 which has 19 regions [repeated 3x across cluster]
# (ctx_internal_ray pid=2128676) 2025-01-28 14:09:36,823 cisTarget    INFO     Running cisTarget for LINC-PINT which has 47 regions
# (ctx_internal_ray pid=2128668) 2025-01-28 14:09:35,209 cisTarget    INFO     Getting cistromes for LAMA5 [repeated 2x across cluster]
# (ctx_internal_ray pid=2128668) 2025-01-28 14:09:38,228 cisTarget    INFO     Running cisTarget for LINC00598 which has 5 regions
# (ctx_internal_ray pid=2128673) 2025-01-28 14:09:41,284 cisTarget    INFO     Annotating motifs for KCTD6
# (ctx_internal_ray pid=2128677) 2025-01-28 14:09:44,750 cisTarget    INFO     Running cisTarget for LINC00621 which has 19 regions
# (ctx_internal_ray pid=2128677) 2025-01-28 14:09:42,775 cisTarget    INFO     Getting cistromes for KIFC3
# (ctx_internal_ray pid=2128672) 2025-01-28 14:09:46,500 cisTarget    INFO     Annotating motifs for LATS2-AS1 [repeated 2x across cluster]
# (ctx_internal_ray pid=2128673) 2025-01-28 14:09:52,159 cisTarget    INFO     Getting cistromes for KCTD6
# (ctx_internal_ray pid=2128679) 2025-01-28 14:09:53,493 cisTarget    INFO     Annotating motifs for LCN12
# (ctx_internal_ray pid=2128673) 2025-01-28 14:09:56,240 cisTarget    INFO     Running cisTarget for LINC00622 which has 20 regions
# (ctx_internal_ray pid=2128672) 2025-01-28 14:09:58,750 cisTarget    INFO     Getting cistromes for LATS2-AS1 [repeated 2x across cluster]
# (ctx_internal_ray pid=2128675) 2025-01-28 14:09:54,323 cisTarget    INFO     Annotating motifs for LARGE2
# (ctx_internal_ray pid=2128672) 2025-01-28 14:10:03,164 cisTarget    INFO     Running cisTarget for LINC01213 which has 15 regions [repeated 2x across cluster]
# (ctx_internal_ray pid=2128679) 2025-01-28 14:10:05,249 cisTarget    INFO     Getting cistromes for LCN12
# (ctx_internal_ray pid=2128675) 2025-01-28 14:10:07,284 cisTarget    INFO     Getting cistromes for LARGE2
# (ctx_internal_ray pid=2128675) 2025-01-28 14:10:13,594 cisTarget    INFO     Running cisTarget for LINC02568 which has 5 regions [repeated 2x across cluster]
# (ctx_internal_ray pid=2128671) 2025-01-28 14:10:35,840 cisTarget    INFO     Annotating motifs for LEMD2
# (ctx_internal_ray pid=2128682) 2025-01-28 14:10:43,905 cisTarget    INFO     Annotating motifs for LIFR-AS1
# (ctx_internal_ray pid=2128669) 2025-01-28 14:10:44,092 cisTarget    INFO     Annotating motifs for LIAS
# (ctx_internal_ray pid=2128674) 2025-01-28 14:10:45,082 cisTarget    INFO     Annotating motifs for LGR4
# (ctx_internal_ray pid=2128667) 2025-01-28 14:10:50,709 cisTarget    INFO     Annotating motifs for LGALS3BP [repeated 2x across cluster]
# (ctx_internal_ray pid=2128682) 2025-01-28 14:10:51,242 cisTarget    INFO     Getting cistromes for LIFR-AS1
# (ctx_internal_ray pid=2128669) 2025-01-28 14:10:52,171 cisTarget    INFO     Getting cistromes for LIAS
# (ctx_internal_ray pid=2128673) 2025-01-28 14:10:56,255 cisTarget    INFO     Annotating motifs for LINC00622 [repeated 3x across cluster]
# (ctx_internal_ray pid=2128680) 2025-01-28 14:10:53,704 cisTarget    INFO     Getting cistromes for LIN7C [repeated 2x across cluster]
# ...
# 2025-01-28 14:59:06,432 cisTarget    INFO     Reading cisTarget database
# Running cisTarget...
# (ctx_internal_ray pid=2142103) 2025-01-28 15:03:19,194 cisTarget    INFO     Running cisTarget for TRIM27 which has 18 regions
# (ctx_internal_ray pid=2142101) 2025-01-28 15:04:27,092 cisTarget    INFO     Annotating motifs for TRPC4AP
# (ctx_internal_ray pid=2142106) 2025-01-28 15:03:20,679 cisTarget    INFO     Running cisTarget for TOB1-AS1 which has 13 regions [repeated 17x across cluster]
# (ctx_internal_ray pid=2142101) 2025-01-28 15:04:34,565 cisTarget    INFO     Getting cistromes for TRPC4AP
# (ctx_internal_ray pid=2142107) 2025-01-28 15:04:31,946 cisTarget    INFO     Annotating motifs for TOM1L2 [repeated 4x across cluster]
# (ctx_internal_ray pid=2142101) 2025-01-28 15:04:35,718 cisTarget    INFO     Running cisTarget for TTC7B which has 16 regions
# (ctx_internal_ray pid=2142108) 2025-01-28 15:04:42,752 cisTarget    INFO     Getting cistromes for TOB1
# (ctx_internal_ray pid=2142098) 2025-01-28 15:04:36,061 cisTarget    INFO     Annotating motifs for TPGS1
# (ctx_internal_ray pid=2142107) 2025-01-28 15:04:42,704 cisTarget    INFO     Getting cistromes for TOM1L2
# (ctx_internal_ray pid=2142107) 2025-01-28 15:04:45,345 cisTarget    INFO     Running cisTarget for TTI1 which has 12 regions
# (ctx_internal_ray pid=2142098) 2025-01-28 15:04:45,289 cisTarget    INFO     Getting cistromes for TPGS1 [repeated 3x across cluster]
# (ctx_internal_ray pid=2142100) 2025-01-28 15:04:55,615 cisTarget    INFO     Annotating motifs for TSC22D1-AS1
# (ctx_internal_ray pid=2142098) 2025-01-28 15:04:48,164 cisTarget    INFO     Running cisTarget for TUSC2 which has 43 regions [repeated 4x across cluster]
# (ctx_internal_ray pid=2142100) 2025-01-28 15:05:07,359 cisTarget    INFO     Getting cistromes for TSC22D1-AS1
# (ctx_internal_ray pid=2142100) 2025-01-28 15:05:09,396 cisTarget    INFO     Running cisTarget for TUT1 which has 38 regions
# (ctx_internal_ray pid=2142097) 2025-01-28 15:05:16,765 cisTarget    INFO     Annotating motifs for TRPC6
# (ctx_internal_ray pid=2142096) 2025-01-28 15:05:26,251 cisTarget    INFO     Annotating motifs for TSC22D3 [repeated 3x across cluster]
# (ctx_internal_ray pid=2142097) 2025-01-28 15:05:26,876 cisTarget    INFO     Getting cistromes for TRPC6
# (ctx_internal_ray pid=2142097) 2025-01-28 15:05:28,059 cisTarget    INFO     Running cisTarget for UBE2E1 which has 16 regions
# (ctx_internal_ray pid=2142095) 2025-01-28 15:05:29,827 cisTarget    INFO     Annotating motifs for TTC7A
# (ctx_internal_ray pid=2142102) 2025-01-28 15:05:31,603 cisTarget    INFO     Annotating motifs for TOB2
# (ctx_internal_ray pid=2142112) 2025-01-28 15:05:31,430 cisTarget    INFO     Getting cistromes for TPCN1 [repeated 2x across cluster]
# (ctx_internal_ray pid=2142112) 2025-01-28 15:05:33,147 cisTarget    INFO     Running cisTarget for UBOX5-AS1 which has 27 regions [repeated 2x across cluster]
# (ctx_internal_ray pid=2142106) 2025-01-28 15:05:38,597 cisTarget    INFO     Annotating motifs for TOB1-AS1
# (ctx_internal_ray pid=2142096) 2025-01-28 15:05:35,468 cisTarget    INFO     Getting cistromes for TSC22D3
# (ctx_internal_ray pid=2142096) 2025-01-28 15:05:37,020 cisTarget    INFO     Running cisTarget for UCKL1-AS1 which has 15 regions
# (ctx_internal_ray pid=2142095) 2025-01-28 15:05:39,256 cisTarget    INFO     Getting cistromes for TTC7A
# (ctx_internal_ray pid=2142095) 2025-01-28 15:05:41,625 cisTarget    INFO     Running cisTarget for UMPS which has 15 regions
# (ctx_internal_ray pid=2142102) 2025-01-28 15:05:43,938 cisTarget    INFO     Running cisTarget for UNG which has 13 regions
# (ctx_internal_ray pid=2142105) 2025-01-28 15:05:44,431 cisTarget    INFO     Annotating motifs for TRAPPC12
# (ctx_internal_ray pid=2142102) 2025-01-28 15:05:40,352 cisTarget    INFO     Getting cistromes for TOB2
# (ctx_internal_ray pid=2142106) 2025-01-28 15:05:47,358 cisTarget    INFO     Getting cistromes for TOB1-AS1
# (ctx_internal_ray pid=2142106) 2025-01-28 15:05:50,674 cisTarget    INFO     Running cisTarget for UNK which has 7 regions
# (ctx_internal_ray pid=2142098) 2025-01-28 15:05:47,035 cisTarget    INFO     Annotating motifs for TUSC2 [repeated 3x across cluster]
# (ctx_internal_ray pid=2142105) 2025-01-28 15:05:54,702 cisTarget    INFO     Getting cistromes for TRAPPC12
# (ctx_internal_ray pid=2142105) 2025-01-28 15:05:57,745 cisTarget    INFO     Running cisTarget for UPB1 which has 14 regions
# (ctx_internal_ray pid=2142104) 2025-01-28 15:05:53,061 cisTarget    INFO     Annotating motifs for TTLL6 [repeated 2x across cluster]
# (ctx_internal_ray pid=2142098) 2025-01-28 15:05:59,797 cisTarget    INFO     Getting cistromes for TUSC2 [repeated 3x across cluster]
# (ctx_internal_ray pid=2142101) 2025-01-28 15:06:03,079 cisTarget    INFO     Running cisTarget for VDR which has 23 regions
# (ctx_internal_ray pid=2142098) 2025-01-28 15:06:02,551 cisTarget    INFO     Running cisTarget for USP30 which has 9 regions [repeated 2x across cluster]
# (ctx_internal_ray pid=2142109) 2025-01-28 15:05:59,319 cisTarget    INFO     Annotating motifs for TNK2
# (ctx_internal_ray pid=2142099) 2025-01-28 15:06:03,619 cisTarget    INFO     Getting cistromes for TRPV6
# (ctx_internal_ray pid=2142104) 2025-01-28 15:06:07,379 cisTarget    INFO     Getting cistromes for TTLL6
# (ctx_internal_ray pid=2142104) 2025-01-28 15:06:10,977 cisTarget    INFO     Running cisTarget for VPS37B which has 40 regions [repeated 2x across cluster]
# (ctx_internal_ray pid=2142111) 2025-01-28 15:06:15,209 cisTarget    INFO     Annotating motifs for TTLL11
# (ctx_internal_ray pid=2142109) 2025-01-28 15:06:11,036 cisTarget    INFO     Getting cistromes for TNK2
# (ctx_internal_ray pid=2142109) 2025-01-28 15:06:15,540 cisTarget    INFO     Running cisTarget for VRK3 which has 14 regions
# (ctx_internal_ray pid=2142111) 2025-01-28 15:06:25,370 cisTarget    INFO     Getting cistromes for TTLL11
# (ctx_internal_ray pid=2142107) 2025-01-28 15:06:19,116 cisTarget    INFO     Annotating motifs for TTI1 [repeated 2x across cluster]
# (ctx_internal_ray pid=2142111) 2025-01-28 15:06:27,219 cisTarget    INFO     Running cisTarget for WASF2 which has 13 regions
# (ctx_internal_ray pid=2142107) 2025-01-28 15:06:30,235 cisTarget    INFO     Getting cistromes for TTI1 [repeated 2x across cluster]
# (ctx_internal_ray pid=2142110) 2025-01-28 15:06:31,999 cisTarget    INFO     Annotating motifs for UBE2Q1
# (ctx_internal_ray pid=2142100) 2025-01-28 15:06:31,577 cisTarget    INFO     Running cisTarget for WDR1 which has 10 regions
# (ctx_internal_ray pid=2142107) 2025-01-28 15:06:34,109 cisTarget    INFO     Running cisTarget for WDR18 which has 28 regions
# (ctx_internal_ray pid=2142110) 2025-01-28 15:06:42,302 cisTarget    INFO     Getting cistromes for UBE2Q1
# (ctx_internal_ray pid=2142108) 2025-01-28 15:06:33,268 cisTarget    INFO     Annotating motifs for TUBE1
# (ctx_internal_ray pid=2142097) 2025-01-28 15:06:43,724 cisTarget    INFO     Annotating motifs for UBE2E1
# (ctx_internal_ray pid=2142110) 2025-01-28 15:06:43,937 cisTarget    INFO     Running cisTarget for WDR33 which has 14 regions
# (ctx_internal_ray pid=2142108) 2025-01-28 15:06:44,222 cisTarget    INFO     Getting cistromes for TUBE1
# (ctx_internal_ray pid=2142108) 2025-01-28 15:06:47,055 cisTarget    INFO     Running cisTarget for WDR88 which has 13 regions
# (ctx_internal_ray pid=2142097) 2025-01-28 15:06:55,003 cisTarget    INFO     Getting cistromes for UBE2E1
# (ctx_internal_ray pid=2142096) 2025-01-28 15:06:55,256 cisTarget    INFO     Annotating motifs for UCKL1-AS1
# (ctx_internal_ray pid=2142097) 2025-01-28 15:06:58,130 cisTarget    INFO     Running cisTarget for WHRN which has 21 regions
# (ctx_internal_ray pid=2142106) 2025-01-28 15:07:01,136 cisTarget    INFO     Annotating motifs for UNK
# (ctx_internal_ray pid=2142096) 2025-01-28 15:07:05,815 cisTarget    INFO     Getting cistromes for UCKL1-AS1
# (ctx_internal_ray pid=2142096) 2025-01-28 15:07:08,858 cisTarget    INFO     Running cisTarget for WWC1 which has 15 regions
# (ctx_internal_ray pid=2142106) 2025-01-28 15:07:09,641 cisTarget    INFO     Getting cistromes for UNK
# (ctx_internal_ray pid=2142105) 2025-01-28 15:07:20,410 cisTarget    INFO     Annotating motifs for UPB1
# (ctx_internal_ray pid=2142106) 2025-01-28 15:07:10,442 cisTarget    INFO     Running cisTarget for ZBTB34 which has 14 regions
# (ctx_internal_ray pid=2142109) 2025-01-28 15:07:25,700 cisTarget    INFO     Annotating motifs for VRK3
# (ctx_internal_ray pid=2142105) 2025-01-28 15:07:27,855 cisTarget    INFO     Getting cistromes for UPB1
# (ctx_internal_ray pid=2142105) 2025-01-28 15:07:30,583 cisTarget    INFO     Running cisTarget for ZCCHC17 which has 19 regions
# (ctx_internal_ray pid=2142112) 2025-01-28 15:07:32,489 cisTarget    INFO     Annotating motifs for UBOX5-AS1
# (ctx_internal_ray pid=2142109) 2025-01-28 15:07:34,086 cisTarget    INFO     Getting cistromes for VRK3
# (ctx_internal_ray pid=2142109) 2025-01-28 15:07:37,105 cisTarget    INFO     Running cisTarget for ZCCHC24 which has 19 regions
# (ctx_internal_ray pid=2142112) 2025-01-28 15:07:41,048 cisTarget    INFO     Getting cistromes for UBOX5-AS1
# (ctx_internal_ray pid=2142111) 2025-01-28 15:07:35,107 cisTarget    INFO     Annotating motifs for WASF2
# (ctx_internal_ray pid=2142112) 2025-01-28 15:07:43,155 cisTarget    INFO     Running cisTarget for ZFAND2B which has 37 regions
# (ctx_internal_ray pid=2142103) 2025-01-28 15:07:44,482 cisTarget    INFO     Annotating motifs for USP2-AS1
# (ctx_internal_ray pid=2142095) 2025-01-28 15:07:44,785 cisTarget    INFO     Annotating motifs for UMPS
# (ctx_internal_ray pid=2142102) 2025-01-28 15:07:45,392 cisTarget    INFO     Annotating motifs for UNG
# (ctx_internal_ray pid=2142111) 2025-01-28 15:07:45,444 cisTarget    INFO     Getting cistromes for WASF2
# (ctx_internal_ray pid=2142111) 2025-01-28 15:07:46,970 cisTarget    INFO     Running cisTarget for ZFHX2 which has 22 regions
# (ctx_internal_ray pid=2142108) 2025-01-28 15:07:50,665 cisTarget    INFO     Annotating motifs for WDR88 [repeated 2x across cluster]
# (ctx_internal_ray pid=2142103) 2025-01-28 15:07:54,627 cisTarget    INFO     Getting cistromes for USP2-AS1
# (ctx_internal_ray pid=2142102) 2025-01-28 15:07:55,566 cisTarget    INFO     Getting cistromes for UNG
# (ctx_internal_ray pid=2142095) 2025-01-28 15:07:55,569 cisTarget    INFO     Getting cistromes for UMPS
# (ctx_internal_ray pid=2142103) 2025-01-28 15:07:57,287 cisTarget    INFO     Running cisTarget for ZFP41 which has 19 regions
# (ctx_internal_ray pid=2142104) 2025-01-28 15:07:58,575 cisTarget    INFO     Annotating motifs for VPS37B
# (ctx_internal_ray pid=2142097) 2025-01-28 15:08:04,724 cisTarget    INFO     Annotating motifs for WHRN
# (ctx_internal_ray pid=2142102) 2025-01-28 15:07:58,202 cisTarget    INFO     Running cisTarget for ZNF16 which has 14 regions [repeated 2x across cluster]
# (ctx_internal_ray pid=2142108) 2025-01-28 15:08:04,860 cisTarget    INFO     Getting cistromes for WDR88
# (ctx_internal_ray pid=2142107) 2025-01-28 15:08:04,943 cisTarget    INFO     Annotating motifs for WDR18
# (ctx_internal_ray pid=2142101) 2025-01-28 15:08:09,603 cisTarget    INFO     Annotating motifs for VDR
# (ctx_internal_ray pid=2142104) 2025-01-28 15:08:11,171 cisTarget    INFO     Running cisTarget for ZNF468 which has 20 regions [repeated 3x across cluster]
# (ctx_internal_ray pid=2142104) 2025-01-28 15:08:09,684 cisTarget    INFO     Getting cistromes for VPS37B [repeated 2x across cluster]
# (ctx_internal_ray pid=2142098) 2025-01-28 15:08:07,514 cisTarget    INFO     Annotating motifs for USP30 [repeated 2x across cluster]
# (ctx_internal_ray pid=2142097) 2025-01-28 15:08:14,477 cisTarget    INFO     Getting cistromes for WHRN
# (ctx_internal_ray pid=2142107) 2025-01-28 15:08:16,404 cisTarget    INFO     Running cisTarget for ZNF652 which has 16 regions [repeated 2x across cluster]
# (ctx_internal_ray pid=2142099) 2025-01-28 15:08:16,086 cisTarget    INFO     Getting cistromes for VGLL4 [repeated 2x across cluster]
# (ctx_internal_ray pid=2142096) 2025-01-28 15:08:11,530 cisTarget    INFO     Annotating motifs for WWC1
# (ctx_internal_ray pid=2142106) 2025-01-28 15:08:24,557 cisTarget    INFO     Annotating motifs for ZBTB34
# (ctx_internal_ray pid=2142099) 2025-01-28 15:08:18,272 cisTarget    INFO     Running cisTarget for ZNF697 which has 20 regions
# (ctx_internal_ray pid=2142096) 2025-01-28 15:08:20,451 cisTarget    INFO     Getting cistromes for WWC1
# (ctx_internal_ray pid=2142096) 2025-01-28 15:08:24,562 cisTarget    INFO     Running cisTarget for ZNF710-AS1 which has 12 regions
# (ctx_internal_ray pid=2142098) 2025-01-28 15:08:30,401 cisTarget    INFO     Getting cistromes for USP30
# (ctx_internal_ray pid=2142100) 2025-01-28 15:08:31,234 cisTarget    INFO     Annotating motifs for WDR1
# (ctx_internal_ray pid=2142101) 2025-01-28 15:08:33,561 cisTarget    INFO     Getting cistromes for VDR
# (ctx_internal_ray pid=2142098) 2025-01-28 15:08:36,727 cisTarget    INFO     Running cisTarget for ZNF768 which has 17 regions
# (ctx_internal_ray pid=2142111) 2025-01-28 15:08:46,507 cisTarget    INFO     Annotating motifs for ZFHX2
# (ctx_internal_ray pid=2142101) 2025-01-28 15:08:40,225 cisTarget    INFO     Running cisTarget for ZNRF3 which has 23 regions
# (ctx_internal_ray pid=2142106) 2025-01-28 15:08:52,933 cisTarget    INFO     Getting cistromes for ZBTB34
# (ctx_internal_ray pid=2142106) 2025-01-28 15:08:58,326 cisTarget    INFO     Running cisTarget for ZRANB2-AS1 which has 20 regions
# (ctx_internal_ray pid=2142100) 2025-01-28 15:08:58,312 cisTarget    INFO     Getting cistromes for WDR1
# (ctx_internal_ray pid=2142105) 2025-01-28 15:09:04,847 cisTarget    INFO     Annotating motifs for ZCCHC17
# (ctx_internal_ray pid=2142100) 2025-01-28 15:09:00,602 cisTarget    INFO     Running cisTarget for ZSWIM8 which has 27 regions
# (ctx_internal_ray pid=2142111) 2025-01-28 15:09:06,267 cisTarget    INFO     Getting cistromes for ZFHX2
# (ctx_internal_ray pid=2142111) 2025-01-28 15:09:08,619 cisTarget    INFO     Running cisTarget for ZYG11B which has 9 regions
# (ctx_internal_ray pid=2142107) 2025-01-28 15:09:11,811 cisTarget    INFO     Annotating motifs for ZNF652 [repeated 3x across cluster]
# (ctx_internal_ray pid=2142105) 2025-01-28 15:09:14,314 cisTarget    INFO     Getting cistromes for ZCCHC17
# (ctx_internal_ray pid=2142099) 2025-01-28 15:09:15,071 cisTarget    INFO     Annotating motifs for ZNF697 [repeated 2x across cluster]
# (ctx_internal_ray pid=2142107) 2025-01-28 15:09:19,411 cisTarget    INFO     Getting cistromes for ZNF652 [repeated 3x across cluster]
# (ctx_internal_ray pid=2142110) 2025-01-28 15:09:21,545 cisTarget    INFO     Annotating motifs for ZNF3 [repeated 2x across cluster]
# (ctx_internal_ray pid=2142096) 2025-01-28 15:09:24,217 cisTarget    INFO     Getting cistromes for ZNF710-AS1 [repeated 3x across cluster]
# (ctx_internal_ray pid=2142098) 2025-01-28 15:09:27,742 cisTarget    INFO     Annotating motifs for ZNF768 [repeated 3x across cluster]
# (ctx_internal_ray pid=2142101) 2025-01-28 15:09:32,622 cisTarget    INFO     Getting cistromes for ZNRF3 [repeated 2x across cluster]
# (ctx_internal_ray pid=2142108) 2025-01-28 15:09:35,234 cisTarget    INFO     Annotating motifs for ZNF423
# (ctx_internal_ray pid=2142109) 2025-01-28 15:09:37,338 cisTarget    INFO     Getting cistromes for ZCCHC24 [repeated 2x across cluster]
# (ctx_internal_ray pid=2142104) 2025-01-28 15:09:39,992 cisTarget    INFO     Annotating motifs for ZNF468 [repeated 3x across cluster]
# (ctx_internal_ray pid=2142111) 2025-01-28 15:09:44,130 cisTarget    INFO     Getting cistromes for ZYG11B [repeated 2x across cluster]
# (ctx_internal_ray pid=2142106) 2025-01-28 15:09:42,626 cisTarget    INFO     Annotating motifs for ZRANB2-AS1 [repeated 3x across cluster]
# (ctx_internal_ray pid=2142100) 2025-01-28 15:09:53,883 cisTarget    INFO     Getting cistromes for ZSWIM8 [repeated 5x across cluster]
# 2025-01-28 15:09:55,999 cisTarget    INFO     Done!
# Processing cisTarget results...
# Writing results to ./results_OT/results/TF_gene/TF_gene_OT_600.csv

# %%
# Specify the folder path
folder_path = outDir

# Get a list of all files in the folder
all_files = [os.path.join(folder_path, f) for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))]

# Filter the list for CSV files
csv_files = [f for f in all_files if f.endswith('.csv')]

# Read all CSV files into a list of DataFrames
dataframes = [pd.read_csv(f,index_col=0) for f in csv_files]

# Combine all DataFrames into a single DataFrame
candidate_df = pd.concat(dataframes, ignore_index=True)

candidate_df = candidate_df.drop_duplicates()
rna_adata = sc.read_h5ad("../../scenic_results/pbmc_tutorial/scRNA/adata.h5ad")
# candidate_df = candidate_df[candidate_df['Gene'].isin(rna_adata.var.index.values)]

candidate_df.rename(columns={'TF': 'Source', 'Gene': 'Target'}, inplace=True)

candidate_df.to_csv(f"./results_OT/results/putative_TF_gene.tsv",sep = '\t')

print("Done")
# Out:
# Done
