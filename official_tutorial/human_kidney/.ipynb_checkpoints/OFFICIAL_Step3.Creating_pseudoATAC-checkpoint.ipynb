# %%
import pandas as pd
import scanpy as sc
import itertools
import anndata
import itertools
import anndata
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import warnings
warnings.simplefilter(action='ignore')
import numpy as np
from sklearn.preprocessing import normalize
from itertools import product
import umap
from collections import Counter
from sklearn.decomposition import PCA
# Out:
# /oscar/data/rsingh47/tpham43/grot_env/lib/python3.9/site-packages/setuptools_scm/_integration/setuptools.py:31: RuntimeWarning:
# ERROR: setuptools==58.1.0 is used in combination with setuptools_scm>=8.x
#
# Your build configuration is incomplete and previously worked by accident!
# setuptools_scm requires setuptools>=61
#
# Suggested workaround if applicable:
#  - migrating from the deprecated setup_requires mechanism to pep517/518
#    and using a pyproject.toml to declare build dependencies
#    which are reliably pre-installed before running the build tools
#
#   warnings.warn(

# %%
# cells = pd.read_csv('./data/GSM6284346_BMMC.metadata.txt.gz',sep = '\t')
# # label_rna['label'] = label_rna[0].str.split('_').str[0]
# # label_rna.columns = ['orig.ident','label']

# cells.index = cells['rna.bc']

# %%
# from collections import Counter
# Counter(cells['celltype'])

# %%
# features = pd.read_csv("./data/GSM6284346_BMMC.peaks.txt.gz",sep =' ')
# features['peak'] = features['chr'] + ":" + features['starts'].astype(str) + "-" + features['end'].astype(str)
# features

# %%
# from scipy.io import mmread
# import gzip

# # Open and read the compressed .mtx file
# with gzip.open('./data/GSM6284346_BMMC.count.matrix.txt.gz', 'rt') as f:
#     matrix = mmread(f)

# # Convert to a dense array if needed
# atac_matrix = matrix.toarray()
# atac_matrix

# %%
# atac_cells = cells['rna.bc']
# atac_peaks = features['peak']
# atac_peaks

# %%
atac_adata = sc.read_h5ad('./data/atac_kidney_control1_lda_3celltypes.h5ad')
# atac_adata = atac_adata[atac_adata.obs['age_group'] == 'adulthood'].copy()

# rna_adata.obs['orig.ident'] = rna_adata.obs[0]
# Counter(atac_adata.obs['age_group'])

# %%
atac_adata
# Out:
# AnnData object with n_obs × n_vars = 1493 × 116859
#     obs: 'barcode', 'patient', 'disease', 'celltype', 'nCount_peaks', 'nFeature_peaks', 'pct_reads_in_peaks', 'UMAP_1', 'UMAP_2', 'n_genes'
#     var: 'peaks', 'chr_no', 'start', 'end', 'Chromosome', 'Start', 'End', 'n_cells'
#     obsm: 'X_lda'

# %%
rna_adata = sc.read_h5ad('./data/rna_data_filtered_pca_1control_3cells.h5ad')
# rna_adata = rna_adata[rna_adata.obs['age_group'] == 'adulthood'].copy()
rna_adata
# Out:
# AnnData object with n_obs × n_vars = 1694 × 4334
#     obs: 'name', 'barcode', 'patient', 'gender', 'disease', 'celltype', 'nCount_RNA', 'nFeature_RNA', 'UMAP_1', 'UMAP_2', 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt'
#     var: 'n_cells', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'celltype_colors', 'hvg', 'log1p', 'neighbors', 'pca', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'

# %%
# Extract cell identifiers
atac_cells = set(atac_adata.obs.celltype)
rna_cells = set(rna_adata.obs.celltype)

# Find common cells
common_cells = list(atac_cells.intersection(rna_cells))

# Output the result
print(f"Number of common cells: {len(common_cells)}")
# print("Common cells:", common_cells)
# Out:
# Number of common cells: 3

# %%
samples = ['Cont1','control1']

# %%
atac_adata = atac_adata[atac_adata.obs.patient.isin(samples)]
rna_adata = rna_adata[rna_adata.obs.patient.isin(samples)]
print(atac_adata)
print(rna_adata)
# Out:
# View of AnnData object with n_obs × n_vars = 1493 × 116859
#     obs: 'barcode', 'patient', 'disease', 'celltype', 'nCount_peaks', 'nFeature_peaks', 'pct_reads_in_peaks', 'UMAP_1', 'UMAP_2', 'n_genes'
#     var: 'peaks', 'chr_no', 'start', 'end', 'Chromosome', 'Start', 'End', 'n_cells'
#     obsm: 'X_lda'
# View of AnnData object with n_obs × n_vars = 1694 × 4334
#     obs: 'name', 'barcode', 'patient', 'gender', 'disease', 'celltype', 'nCount_RNA', 'nFeature_RNA', 'UMAP_1', 'UMAP_2', 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt'
#     var: 'n_cells', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'celltype_colors', 'hvg', 'log1p', 'neighbors', 'pca', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'

# %%
cells = ['CNT_PC','DCT','ENDO']

# %%
atac_adata = atac_adata[atac_adata.obs.celltype.isin(cells)]
rna_adata = rna_adata[rna_adata.obs.celltype.isin(cells)]
print(atac_adata)
print(rna_adata)
# Out:
# View of AnnData object with n_obs × n_vars = 1493 × 116859
#     obs: 'barcode', 'patient', 'disease', 'celltype', 'nCount_peaks', 'nFeature_peaks', 'pct_reads_in_peaks', 'UMAP_1', 'UMAP_2', 'n_genes'
#     var: 'peaks', 'chr_no', 'start', 'end', 'Chromosome', 'Start', 'End', 'n_cells'
#     obsm: 'X_lda'
# View of AnnData object with n_obs × n_vars = 1694 × 4334
#     obs: 'name', 'barcode', 'patient', 'gender', 'disease', 'celltype', 'nCount_RNA', 'nFeature_RNA', 'UMAP_1', 'UMAP_2', 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt'
#     var: 'n_cells', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'celltype_colors', 'hvg', 'log1p', 'neighbors', 'pca', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'

# %%
from collections import Counter
Counter(atac_adata.obs['celltype'])
# Out:
# Counter({'CNT_PC': 686, 'DCT': 523, 'ENDO': 284})

# %%
from collections import Counter
Counter(rna_adata.obs['celltype'])
# Out:
# Counter({'CNT_PC': 881, 'DCT': 545, 'ENDO': 268})

# %%
# desired_cell_types = ['GMP', 'CLP', 'LMPP']

sc.pp.filter_cells(rna_adata, min_genes=200)
sc.pp.filter_genes(rna_adata, min_cells=3)
rna_adata.obs.columns = rna_adata.obs.columns.astype(str)
rna_adata.var.columns = rna_adata.var.columns.astype(str)
# rna_adata = rna_adata[rna_adata.obs['celltype'].isin(desired_cell_types)]
# rna_adata = rna_adata[rna_adata.obs['celltype'].isin(desired_cell_types)]

rna_adata
# Out:
# AnnData object with n_obs × n_vars = 1693 × 4334
#     obs: 'name', 'barcode', 'patient', 'gender', 'disease', 'celltype', 'nCount_RNA', 'nFeature_RNA', 'UMAP_1', 'UMAP_2', 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt'
#     var: 'n_cells', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'celltype_colors', 'hvg', 'log1p', 'neighbors', 'pca', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'

# %%
sc.pp.filter_cells(atac_adata, min_genes=200)
sc.pp.filter_genes(atac_adata, min_cells=3)
# atac_adata = atac_adata[atac_adata.obs['celltype'].isin(desired_cell_types)]

# atac_adata.write_h5ad("./data/atac_downsampled_bmmc.h5ad")
atac_adata
# Out:
# AnnData object with n_obs × n_vars = 1493 × 116859
#     obs: 'barcode', 'patient', 'disease', 'celltype', 'nCount_peaks', 'nFeature_peaks', 'pct_reads_in_peaks', 'UMAP_1', 'UMAP_2', 'n_genes'
#     var: 'peaks', 'chr_no', 'start', 'end', 'Chromosome', 'Start', 'End', 'n_cells'
#     obsm: 'X_lda'

# %%
# rna_adata.write_h5ad("./data/rna_snare_full.h5ad")

# %%
# # Downsample 80%
# np.random.seed(42)

# downsample_fraction = 1
# num_cells = rna_adata.shape[0]
# downsample_size = int(num_cells * downsample_fraction)

# # Randomly select indices
# downsample_indices = np.random.choice(num_cells, size=downsample_size, replace=False)

# # Subset the AnnData object
adata_downsampled = rna_adata.copy()

# %%
downsampled_id = adata_downsampled.obs['celltype'].to_list()
adata_downsampled
# Out:
# AnnData object with n_obs × n_vars = 1693 × 4334
#     obs: 'name', 'barcode', 'patient', 'gender', 'disease', 'celltype', 'nCount_RNA', 'nFeature_RNA', 'UMAP_1', 'UMAP_2', 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt'
#     var: 'n_cells', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'celltype_colors', 'hvg', 'log1p', 'neighbors', 'pca', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'

# %%
adata_downsampled.obs.columns = adata_downsampled.obs.columns.astype(str)
adata_downsampled.var.columns = adata_downsampled.var.columns.astype(str)

# %%
# adata_downsampled.write_h5ad("./data/rna_data_filtered_pca_downsampled_ct.h5ad")

# %%
# adata_downsampled = sc.read_h5ad("./data/rna_data_filtered_pca_downsampled_3controls.h5ad")
# # adata_downsampled.obs.index = adata_downsampled.obs['rna.bc']
# adata_downsampled.obs

# %%
adata_downsampled
# Out:
# AnnData object with n_obs × n_vars = 1693 × 4334
#     obs: 'name', 'barcode', 'patient', 'gender', 'disease', 'celltype', 'nCount_RNA', 'nFeature_RNA', 'UMAP_1', 'UMAP_2', 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt'
#     var: 'n_cells', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'celltype_colors', 'hvg', 'log1p', 'neighbors', 'pca', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'

# %%
rna = adata_downsampled.obsm['X_pca']
rna.shape
# Out:
# (1693, 50)

# %%
import numpy as np
from sklearn.decomposition import PCA
# Sample label array (replace with your own label array)
label_array = np.array(adata_downsampled.obs['celltype'].to_list())

# Get unique labels
unique_labels = np.unique(label_array)
rna_pca=PCA(n_components=2)
Xrna_2Dpca=rna_pca.fit_transform(rna)
# Plot PCA-transformed data with labels
plt.figure()

# Plot each unique label separately
for lab in unique_labels:
    mask = (label_array == lab)
    plt.scatter(Xrna_2Dpca[mask, 0], Xrna_2Dpca[mask, 1], s=5, label=lab)

# plt.legend(loc='best', shadow=False)
plt.title('Human Cortex Gene Expression Domain Before Alignment')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.show()

# %%
# atac_adata = sc.read_h5ad("./data/filtered_atac_adata_bmmc.h5ad_lda.h5ad")
atac_adata
# Out:
# AnnData object with n_obs × n_vars = 1493 × 116859
#     obs: 'barcode', 'patient', 'disease', 'celltype', 'nCount_peaks', 'nFeature_peaks', 'pct_reads_in_peaks', 'UMAP_1', 'UMAP_2', 'n_genes'
#     var: 'peaks', 'chr_no', 'start', 'end', 'Chromosome', 'Start', 'End', 'n_cells'
#     obsm: 'X_lda'

# %%
sc.pp.filter_cells(atac_adata, min_genes=200)
sc.pp.filter_genes(atac_adata, min_cells=3)
atac_adata
# Out:
# AnnData object with n_obs × n_vars = 1493 × 116859
#     obs: 'barcode', 'patient', 'disease', 'celltype', 'nCount_peaks', 'nFeature_peaks', 'pct_reads_in_peaks', 'UMAP_1', 'UMAP_2', 'n_genes'
#     var: 'peaks', 'chr_no', 'start', 'end', 'Chromosome', 'Start', 'End', 'n_cells'
#     obsm: 'X_lda'

# %%
# Find common indices
# common_indices = atac_adata.obs.index.intersection(adata_downsampled.obs.index)

# Subset atac_adata to retain only these indices
# atac_adata = atac_adata[common_indices].copy()

# %%
atac = atac_adata.obsm['X_lda']
atac
# Out:
# array([[2.69784173e-03, 2.69784173e-03, 3.59712230e-03, ...,
#         8.99280576e-04, 1.79856115e-03, 3.05755396e-01],
#        [1.60256410e-03, 3.20512821e-03, 3.20512821e-03, ...,
#         8.01282051e-04, 1.60256410e-03, 2.52403846e-01],
#        [5.20134228e-03, 3.35570470e-04, 2.51677852e-03, ...,
#         4.86577181e-03, 4.86577181e-03, 3.69127517e-03],
#        ...,
#        [3.30161196e-03, 1.94212468e-03, 3.69003690e-03, ...,
#         4.66109924e-03, 2.33054962e-03, 6.21479899e-03],
#        [5.39519827e-04, 2.69759914e-04, 1.07903965e-03, ...,
#         2.69759914e-04, 3.23711896e-03, 2.15807931e-03],
#        [7.85669390e-04, 1.57133878e-04, 1.72847266e-03, ...,
#         5.49968573e-03, 9.42803268e-04, 1.57133878e-04]])

# %%
import numpy as np

# Sample label array (replace with your own label array)
label_array_atac = np.array(atac_adata.obs['celltype'].to_list())

# Get unique labels
unique_labels = np.unique(label_array_atac)
pca=PCA(n_components=2)
Yatac_2Dpca=pca.fit_transform(atac)
# Plot PCA-transformed data with labels
plt.figure()

# Plot each unique label separately
for lab in unique_labels:
    mask = (label_array_atac == lab)
    plt.scatter(Yatac_2Dpca[mask, 0], Yatac_2Dpca[mask, 1], s=5, label=lab)

# plt.legend(loc='best', shadow=False)
plt.title('Human Cortex ATAC Domain Before Alignment')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.show()

# %%
# rna_df = pd.DataFrame(rna)
# rna_df['label'] = label_array
# rna_df.to_csv("rna_kidney_50pca.tsv",sep = '\t')

# %%
# atac_df = pd.DataFrame(atac)
# atac_df['label'] = label_array_atac
# atac_df.to_csv("atac_kidney_50pca.tsv",sep = '\t')

# %%
rna = normalize(rna)

# %%
atac = normalize(atac)

# %%
# rna_raw.obs['annotation'] = rna_adata.obs['orig.ident'].map(atac_adata.obs.set_index('orig.ident')['n_genes'])

# sum(atac_adata.obs['n_genes']!=0)
# sum(rna_adata.obs['annotation']=='NaN')
# from collections import Counter
# Counter(rna_adata.obs['annotation'])

# %%
import numpy as np
from sklearn.preprocessing import normalize
#load the data:
# Xrna=np.loadtxt("./x_rna.csv",delimiter = "\t")
# Yatac=np.loadtxt("./y_atac.csv",delimiter = "\t")
print("Dimensions of input datasets are: ", "X(rna)= ", rna.shape, " Y(atac)= ", atac.shape)
# Out:
# Dimensions of input datasets are:  X(rna)=  (1693, 50)  Y(atac)=  (1493, 50)

# %%
from scotplus.utils.alignment import compute_graph_distances
D_rna = compute_graph_distances(rna.astype('float32'), n_neighbors=50, mode='connectivity')
D_atac = compute_graph_distances(atac.astype('float32'), n_neighbors=50, mode='connectivity')

# %%
from scotplus.solvers import SinkhornSolver
from sklearn.preprocessing import normalize
import matplotlib.pylab as plt
from sklearn.decomposition import PCA

import torch
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
atac_adata.shape
# Out:
# (1493, 116859)

# %%
from scotplus.utils.alignment import get_barycentre

scot = SinkhornSolver(tol_uot=1e-5, nits_uot=500, nits_bcd=20,device=device)
pi_samp,_,pi_feat = scot.ugw(D_rna,D_atac, rho = (0.05, 0.05), eps = 1e-4, verbose = True,device=device) #RNA on to atac
pi_samp = pi_samp.cpu()
aligned_rna = get_barycentre(torch.tensor(atac,dtype = torch.float32), (pi_samp.cpu()))
# Xrna_integrated=atac
# Yatac_subsamp_integrated=aligned_rna
# Out:
# BCD Iteration 1 - Loss: 0.036142, 0.036473
# BCD Iteration 2 - Loss: 0.019801, 0.020513
# BCD Iteration 3 - Loss: 0.018170, 0.019022
# BCD Iteration 4 - Loss: 0.018041, 0.018921
# BCD Iteration 5 - Loss: 0.018010, 0.018899
# BCD Iteration 6 - Loss: 0.017998, 0.018890
# BCD Iteration 7 - Loss: 0.017990, 0.018885
# BCD Iteration 8 - Loss: 0.017986, 0.018883
# BCD Iteration 9 - Loss: 0.017984, 0.018882
# BCD Iteration 10 - Loss: 0.017983, 0.018881

# %%
transfer_accuracy(aligned_rna,atac,label_array,label_array_atac,5)
# Out:
# 0.6603662138216184

# %%
# plot a corner of the heatmap to get a sense for density
plt.figure(figsize=(8, 6))
plt.imshow(pi_samp.cpu(), cmap='Blues', interpolation='nearest')
plt.colorbar(label='Value')
plt.title('Heatmap of Sample Matrix')
plt.show()

# %%
from scotplus.utils.alignment import get_barycentre
aligned_rna = get_barycentre(torch.tensor(atac,dtype = torch.float32), (pi_samp.cpu()))
atac.shape, aligned_rna.shape
# Out:
# ((1493, 50), torch.Size([1693, 50]))

# %%
Xrna_integrated=atac
Yatac_subsamp_integrated=aligned_rna
concatenated=np.concatenate((Xrna_integrated,Yatac_subsamp_integrated), axis=0)

concatenated_pc=pca.transform(concatenated)
Xrna_integrated_pc=concatenated_pc[0:Xrna_integrated.shape[0],:]
Yatac_subsamp_integrated_pc=concatenated_pc[Xrna_integrated.shape[0]:,:]

x_labels = np.array(label_array_atac)
concat_labels = np.concatenate((label_array_atac,label_array),axis=0)
concat_pc = np.concatenate((Xrna_integrated_pc,Yatac_subsamp_integrated_pc), axis=0)
for label in unique_labels:
    mask = (label_array == label)
    plt.scatter(Yatac_subsamp_integrated_pc[mask, 0], Yatac_subsamp_integrated_pc[mask, 1], s=20, alpha=0.3, label = label)
    
    
plt.title('Unbalanced Human Cortex Gene Expression Domain After Alignment')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.show()

# %%
from sklearn.neighbors import KNeighborsClassifier
def transfer_accuracy(domain1, domain2, type1, type2,n):
	"""
	Metric from UnionCom: "Label Transfer Accuracy"
	"""
	knn = KNeighborsClassifier(n_neighbors=n)
	knn.fit(domain2, type2)
	type1_predict = knn.predict(domain1)
	count = 0
	for label1, label2 in zip(type1_predict, type1):
		if label1 == label2:
			count += 1
	return count / len(type1)

# %%
import numpy as np
from scipy.sparse import csr_matrix

def pseudo_atac_generation(coupling_matrix,original_atac,threshold = 0.2):
    c_m_transpose = coupling_matrix.T
    weighted_coupling_matrix = c_m_transpose/ c_m_transpose.sum(1).reshape(-1, 1)
    sparse_weighted_c_m = csr_matrix(weighted_coupling_matrix)
    
    dense_atac = sparse_weighted_c_m.dot(original_atac)
    mask = dense_atac.toarray() > threshold

# Replace values greater than the threshold with 1, and others with 0
    new_atac = np.where(mask, 1, 0)
    
    return new_atac

# %%
unfiltered_atac = pi_samp @ atac_adata.X.todense() / pi_samp.sum(1).reshape(-1, 1)

# %%
dense_atac = unfiltered_atac.numpy()

# %%
dense_atac
# Out:
# array([[9.32697979e-03, 0.00000000e+00, 2.00680774e-22, ...,
#         1.09657963e-21, 1.70401930e-12, 1.55010456e-23],
#        [9.09588097e-03, 3.09270260e-18, 1.37429942e-26, ...,
#         1.62268815e-04, 6.42943046e-13, 5.18236131e-10],
#        [5.17226247e-06, 2.96291263e-29, 1.00600480e-08, ...,
#         0.00000000e+00, 1.06995564e-04, 2.19324576e-24],
#        ...,
#        [4.42310978e-18, 8.61842496e-08, 0.00000000e+00, ...,
#         0.00000000e+00, 9.06133456e-18, 1.11920407e-06],
#        [6.06075673e-04, 1.12800874e-07, 6.86274611e-08, ...,
#         1.29187831e-03, 3.75853411e-03, 3.59366988e-18],
#        [3.37717685e-02, 1.93403531e-02, 0.00000000e+00, ...,
#         5.31384646e-02, 0.00000000e+00, 3.51075209e-05]])

# %%
####nearest neighbor

###nearest_neighbor
log_pi_sample = np.log(pi_samp)
column_indices = np.argmax(log_pi_sample, axis=1)
len(column_indices)

nearest_neighbor = atac_adata.X[column_indices]

### preprocessing atac seq
atac_adata.var.index = atac_adata.var.index.astype(str)
# rna_adata.obs.index = adata_downsampled.obs.index.astype(str)
atac_adata.var.columns = atac_adata.var.columns.astype(str)
# rna_adata.obs.columns = aligned_rna.obs.columns.astype(str)
projected_atac =  sc.AnnData(nearest_neighbor,
                      var = atac_adata.var,
                      obs = rna_adata.obs[['celltype']]
    #                       var_names='gene_symbols'                # use gene symbols for the variable names (variables-axis index
                      )
# projected_atac.var.index = projected_atac.var.index.astype(str)

# projected_atac.write_h5ad('./data/pseudo_atac_0.1_updated.h5ad')

# atac_adata.obs.index = atac_adata.obs[0] 
# atac_adata  = atac_adata[joint_list,:]
sc.pp.filter_cells(projected_atac, min_genes=200) #filter out cells that express less than 200 genes and genes expressed in less than 3 cells
sc.pp.filter_genes(projected_atac, min_cells=3)
projected_atac.obs.columns = projected_atac.obs.columns.astype(str)
projected_atac.var.columns = projected_atac.var.columns.astype(str)
projected_atac.obs['orig.ident'] = projected_atac.obs.index
projected_atac.var['features'] = projected_atac.var.index
# projected_atac.obs['celltype'] = projected_atac.obs['label']


projected_atac.var[['chr_no', 'start','end']] = projected_atac.var['features'].str.split('-|:', expand=True)
projected_atac.var['start'] = projected_atac.var['start'].astype(str)
projected_atac.var['end'] = projected_atac.var['end'].astype(str)
projected_atac.var['Chromosome'] = projected_atac.var['chr_no']
projected_atac.var['chr_no'] = projected_atac.var['chr_no'].str.replace('chr', '')
projected_atac.var['Start'] = projected_atac.var['start']
projected_atac.var['End'] = projected_atac.var['end']
# projected_atac.var['Cell_ID'] = projected_atac.var['start']
# projected_atac.uns['mod'] = 'atac'

projected_atac.write_h5ad('./data/pseudo_atac_kidney_nn.h5ad')

# %%
# Keep top 5 values per row
def keep_top_n_per_row(tensor, n):
    # Sort each row in descending order
    sorted_tensor, _ = torch.sort(tensor, descending=True, dim=1)
    # Get the threshold (n-th largest value) for each row
    thresholds = sorted_tensor[:, n - 1].unsqueeze(1)
    # Keep values >= threshold, set others to 0
    return torch.where(tensor >= thresholds, tensor, torch.zeros_like(tensor))

# %%
import numpy as np
from scipy.sparse import csr_matrix
####binarized
curated_pi_samp = keep_top_n_per_row(torch.tensor(pi_samp, dtype=torch.float32), 20)
# c_m_transpose = (curated_pi_samp.cpu().T)

unfiltered_atac = curated_pi_samp @ atac_adata.X.todense() / curated_pi_samp.sum(1).reshape(-1, 1)

dense_atac = unfiltered_atac.numpy()
### preprocessing atac seq
atac_adata.var.index = atac_adata.var.index.astype(str)
# rna_adata.obs.index = adata_downsampled.obs.index.astype(str)
atac_adata.var.columns = atac_adata.var.columns.astype(str)
# rna_adata.obs.columns = aligned_rna.obs.columns.astype(str)
projected_atac =  sc.AnnData(dense_atac,
                      var = atac_adata.var,
                      obs = adata_downsampled.obs[['celltype']]
    #                       var_names='gene_symbols'                # use gene symbols for the variable names (variables-axis index
                      )
# projected_atac.var.index = projected_atac.var.index.astype(str)

# projected_atac.write_h5ad('./data/pseudo_atac_0.1_updated.h5ad')

# atac_adata.obs.index = atac_adata.obs[0] 
# atac_adata  = atac_adata[joint_list,:]
# sc.pp.filter_cells(projected_atac, min_genes=200) #filter out cells that express less than 200 genes and genes expressed in less than 3 cells
# sc.pp.filter_genes(projected_atac, min_cells=3)
projected_atac.obs.columns = projected_atac.obs.columns.astype(str)
projected_atac.var.columns = projected_atac.var.columns.astype(str)
projected_atac.obs['orig.ident'] = projected_atac.obs.index
projected_atac.var['features'] = projected_atac.var.index
# projected_atac.obs['celltype'] = projected_atac.obs['label']


projected_atac.var[['chr_no', 'start','end']] = projected_atac.var['features'].str.split('-|:', expand=True)
projected_atac.var['start'] = projected_atac.var['start'].astype(str)
projected_atac.var['end'] = projected_atac.var['end'].astype(str)
projected_atac.var['Chromosome'] = projected_atac.var['chr_no']
projected_atac.var['chr_no'] = projected_atac.var['chr_no'].str.replace('chr', '')
projected_atac.var['Start'] = projected_atac.var['start']
projected_atac.var['End'] = projected_atac.var['end']
# projected_atac.var['Cell_ID'] = projected_atac.var['start']
projected_atac.uns['mod'] = 'atac'

projected_atac.write_h5ad('./data/pseudo_atac_unfiltered_kidney.h5ad')

# %%
curated_pi_samp = keep_top_n_per_row(torch.tensor(pi_samp, dtype=torch.float32), 20)
# c_m_transpose = (curated_pi_samp.cpu().T)

unfiltered_atac = curated_pi_samp @ atac_adata.X.todense() / curated_pi_samp.sum(1).reshape(-1, 1)
threshold = 0.1

mask = unfiltered_atac > threshold
new_atac = np.where(mask, 1, 0)
print(np.sum(new_atac))
### preprocessing atac seq
atac_adata.var.index = atac_adata.var.index.astype(str)
# rna_adata.obs.index = adata_downsampled.obs.index.astype(str)
atac_adata.var.columns = atac_adata.var.columns.astype(str)
# rna_adata.obs.columns = aligned_rna.obs.columns.astype(str)
projected_atac =  sc.AnnData(new_atac,
                      var = atac_adata.var,
                      obs = adata_downsampled.obs[['celltype']]
    #                       var_names='gene_symbols'                # use gene symbols for the variable names (variables-axis index
                      )
# projected_atac.var.index = projected_atac.var.index.astype(str)

# projected_atac.write_h5ad('./data/pseudo_atac_0.1_updated.h5ad')

# atac_adata.obs.index = atac_adata.obs[0] 
# atac_adata  = atac_adata[joint_list,:]
sc.pp.filter_cells(projected_atac, min_genes=200) #filter out cells that express less than 200 genes and genes expressed in less than 3 cells
sc.pp.filter_genes(projected_atac, min_cells=3)
projected_atac.obs.columns = projected_atac.obs.columns.astype(str)
projected_atac.var.columns = projected_atac.var.columns.astype(str)
projected_atac.obs['orig.ident'] = projected_atac.obs.index
projected_atac.var['features'] = projected_atac.var.index
# projected_atac.obs['celltype'] = projected_atac.obs['cel']


projected_atac.var[['chr_no', 'start','end']] = projected_atac.var['features'].str.split('-|:', expand=True)
projected_atac.var['start'] = projected_atac.var['start'].astype(int)
projected_atac.var['end'] = projected_atac.var['end'].astype(int)
projected_atac.var['Chromosome'] = projected_atac.var['chr_no']
projected_atac.var['chr_no'] = projected_atac.var['chr_no'].str.replace('chr', '')
projected_atac.var['Start'] = projected_atac.var['start']
projected_atac.var['End'] = projected_atac.var['end']
# projected_atac.var['Cell_ID'] = projected_atac.var['start']
# projected_atac.uns['mod'] = 'atac'

projected_atac.write_h5ad('./data/pseudo_atac_20_0.1.h5ad')
# Out:
# 24436517

# %%
###baseline
log_pi_sample = np.log(pi_samp.T.cpu())
column_indices = np.argmax(log_pi_sample, axis=1)
len(column_indices)

baseline = atac_adata.X[column_indices]

# %%
baseline.shape

# %%
# ### preprocessing atac seq
# import numpy as np
# from scipy.sparse import csr_matrix
# atac_adata.var.index = atac_adata.var.index.astype(str)
# # rna_adata.obs.index = adata_downsampled.obs.index.astype(str)
# atac_adata.var.columns = atac_adata.var.columns.astype(str)
# # rna_adata.obs.columns = aligned_rna.obs.columns.astype(str)
# projected_atac =  sc.AnnData(csr_matrix(baseline),
#                       var = atac_adata.var,
#                       obs = adata_downsampled.obs[['author_cell_type']]
#     #                       var_names='gene_symbols'                # use gene symbols for the variable names (variables-axis index
#                       )
# # projected_atac.var.index = projected_atac.var.index.astype(str)

# # projected_atac.write_h5ad('./data/pseudo_atac_0.1_updated.h5ad')

# # atac_adata.obs.index = atac_adata.obs[0] 
# # atac_adata  = atac_adata[joint_list,:]
# sc.pp.filter_cells(projected_atac, min_genes=200) #filter out cells that express less than 200 genes and genes expressed in less than 3 cells
# sc.pp.filter_genes(projected_atac, min_cells=3)
# projected_atac.obs.columns = projected_atac.obs.columns.astype(str)
# projected_atac.var.columns = projected_atac.var.columns.astype(str)
# projected_atac.obs['orig.ident'] = projected_atac.obs.index
# projected_atac.var['features'] = projected_atac.var.index
# # projected_atac.obs['celltype'] = projected_atac.obs['label']


# projected_atac.var[['chr_no', 'start','end']] = projected_atac.var['features'].str.split('-|:', expand=True)
# projected_atac.var['start'] = projected_atac.var['start'].astype(int)
# projected_atac.var['end'] = projected_atac.var['end'].astype(int)
# projected_atac.var['Chromosome'] = projected_atac.var['chr_no']
# projected_atac.var['chr_no'] = projected_atac.var['chr_no'].str.replace('chr', '')
# projected_atac.var['Start'] = projected_atac.var['start']
# projected_atac.var['End'] = projected_atac.var['end']
# # projected_atac.var['Cell_ID'] = projected_atac.var['start']
# projected_atac.uns['mod'] = 'atac'

# projected_atac.write_h5ad('./data/atac_nearest_neighbor_baseline.h5ad')
