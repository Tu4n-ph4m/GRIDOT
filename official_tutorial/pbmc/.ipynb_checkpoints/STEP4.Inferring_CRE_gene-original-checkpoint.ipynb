# %%
# import dill
import scanpy as sc
import os
import warnings
warnings.filterwarnings("ignore")
import pandas as pd
import numpy as np

# import pyranges
# Set stderr to null to avoid strange messages from ray
import sys
_stderr = sys.stderr
null = open(os.devnull,'wb')
from scipy.sparse import issparse


import itertools
import anndata
import itertools
import anndata
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import warnings
warnings.simplefilter(action='ignore')
import numpy as np
from sklearn.preprocessing import normalize

from itertools import product
import umap
from collections import Counter
from sklearn.decomposition import PCA
from gridot.utils import *
from gridot.train import *

# %%
atac_anndata = sc.read_h5ad('./data/pseudo_atac_pbmc_binarized_20_20.h5ad')
atac_anndata
# Out:
# AnnData object with n_obs × n_vars = 2664 × 104227
#     obs: 'celltype', 'n_genes', 'orig.ident'
#     var: 'Chromosome', 'Start', 'End', 'n_cells', 'features', 'chr_no', 'start', 'end'

# %%
atac_anndata.var['chr_no'] = atac_anndata.var['Chromosome']
atac_anndata.var['start'] = atac_anndata.var['Start']
atac_anndata.var['end'] = atac_anndata.var['End']

# %%
rna_anndata = sc.read_h5ad('./data/adata.h5ad')

# Check if raw data exists
if rna_anndata.raw is not None:
    # Access the raw data
    raw_data = rna_anndata.raw.X
    raw_obs = rna_anndata.obs.copy()  # Cell metadata (unchanged)
    raw_var = rna_anndata.raw.var.copy()  # Gene metadata (original raw genes)

    # Create a new AnnData object using the raw data
    rna_anndata = sc.AnnData(X=raw_data, obs=raw_obs, var=raw_var)

    # Print the new raw AnnData object to verify
    print(rna_anndata)
else:
    print("The AnnData object does not contain raw data.")
# Out:
# AnnData object with n_obs × n_vars = 2664 × 21255
#     obs: 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'ingest_celltype_label', 'leiden_res_0.8', 'celltype'
#     var: 'gene_ids', 'feature_types', 'genome', 'n_cells', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts'

# %%
celltypes = rna_anndata.obs['celltype'].unique()

# %%
schema_reference = 'rna'
marker_gene = 'CD38'
distance_threshold = 1e5
device = 'cuda:0'
num_components = 50
gene_file = "./data/gencode.v38.annotation.gff3"
folder_path = './testing_results'

# %%
atac_adata, rna_adata = preprocessing_adata(atac_anndata,rna_anndata,gene_file=gene_file)

print("Processing multimodal")
preprocess_multimodal(rna_adata,atac_adata)
print("CRE-gene relationship")
run_gridot_cell_population(rna_adata,atac_adata,schema_reference='rna',marker_gene = marker_gene,distance_threshold=distance_threshold,device = device,folder_path = folder_path)
# Out:
# Pre-processing scATAC-seq...
# AnnData object with n_obs × n_vars = 2664 × 104227
#     obs: 'celltype', 'n_genes', 'orig.ident'
#     var: 'Chromosome', 'Start', 'End', 'n_cells', 'features', 'chr_no', 'start', 'end'
# Pre-processing scRNA-seq...
# AnnData object with n_obs × n_vars = 2664 × 21167
#     obs: 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'ingest_celltype_label', 'leiden_res_0.8', 'celltype'
#     var: 'gene_ids', 'feature_types', 'genome', 'n_cells', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'features'
# Adding start site to meta file...
# Processing multimodal
# CRE-gene relationship
# Identifying candidate pairs within 100000.0 bp
# 244140
# Running quadratic program... done.
# Cell with highest CD38 expression: ('CTAGCTTGTTGAGGTC-1', 1124)
# Expression level:   (0, 0)	5.438936233520508
# WARNING: Trying to run `tl.dpt` without prior call of `tl.diffmap`. Falling back to `tl.diffmap` with default parameters.
# Epoch 0 (18.48 seconds): train loss 1016.12
# Epoch Inference (30.78 seconds): test loss 988.70
# Total Time: 49.721131801605225 seconds
# Folder created at: ./testing_results

# %%
candidates_df = identify_all_peak_gene_link_candidates(rna_anndata,atac_anndata,distance_thresh=1e6)
candidates_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /oscar/data/rsingh47/tpham43/gridot_env/lib/python3.11/site-packages/pandas/core/indexes/base.py:3800, in Index.get_loc(self, key, method, tolerance)
#    3799 try:
# -> 3800     return self._engine.get_loc(casted_key)
#    3801 except KeyError as err:
#
# File /oscar/data/rsingh47/tpham43/gridot_env/lib/python3.11/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File /oscar/data/rsingh47/tpham43/gridot_env/lib/python3.11/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'chr_no'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 candidates_df = identify_all_peak_gene_link_candidates(rna_anndata,atac_anndata,distance_thresh=1e6)
#       2 candidates_df
#
# File /oscar/data/rsingh47/tpham43/GRIDOT/src/gridot/utils.py:296, in identify_all_peak_gene_link_candidates(rna_adata, atac_adata, distance_thresh, rna_chr_key, rna_txstart_key, atac_chr_key, atac_start_key, atac_end_key)
#     293 for chr_no in sorted(list(set(atac_adata.var[atac_chr_key].values))):
#     295 	filtered_atac_df = atac_adata.var[atac_adata.var[atac_chr_key] == chr_no]
# --> 296 	filtered_gene_df = rna_adata.var[rna_adata.var[rna_chr_key] == chr_no]
#     297 	filtered_gene_symbols = filtered_gene_df.index.values
#     299 	peak_data = filtered_atac_df[[atac_start_key,atac_end_key]].values
#
# File /oscar/data/rsingh47/tpham43/gridot_env/lib/python3.11/site-packages/pandas/core/frame.py:3805, in DataFrame.__getitem__(self, key)
#    3803 if self.columns.nlevels > 1:
#    3804     return self._getitem_multilevel(key)
# -> 3805 indexer = self.columns.get_loc(key)
#    3806 if is_integer(indexer):
#    3807     indexer = [indexer]
#
# File /oscar/data/rsingh47/tpham43/gridot_env/lib/python3.11/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3800     return self._engine.get_loc(casted_key)
#    3801 except KeyError as err:
# -> 3802     raise KeyError(key) from err
#    3803 except TypeError:
#    3804     # If we have a listlike key, _check_indexing_error will raise
#    3805     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3806     #  the TypeError.
#    3807     self._check_indexing_error(key)
#
# KeyError: 'chr_no'

# %%
atac_adata.var
# Out:
#                                                  0                  features  \
# chr2:148881654-148881927  chr2:148881654-148881927  chr2:148881654-148881927
# chr8:99495798-99496023      chr8:99495798-99496023    chr8:99495798-99496023
# chr22:21735444-21736416    chr22:21735444-21736416   chr22:21735444-21736416
# chr3:28241304-28242015      chr3:28241304-28242015    chr3:28241304-28242015
# chr5:154627638-154628386  chr5:154627638-154628386  chr5:154627638-154628386
# ...                                            ...                       ...
# chr15:71448618-71449096    chr15:71448618-71449096   chr15:71448618-71449096
# chr15:71792584-71792805    chr15:71792584-71792805   chr15:71792584-71792805
# chr15:75810000-75810429    chr15:75810000-75810429   chr15:75810000-75810429
# chr15:76805231-76805523    chr15:76805231-76805523   chr15:76805231-76805523
# chr15:77885067-77885439    chr15:77885067-77885439   chr15:77885067-77885439
#
#                          chr_no      start        end Chromosome      Start  \
# chr2:148881654-148881927      2  148881654  148881927       chr2  148881654
# chr8:99495798-99496023        8   99495798   99496023       chr8   99495798
# chr22:21735444-21736416      22   21735444   21736416      chr22   21735444
# chr3:28241304-28242015        3   28241304   28242015       chr3   28241304
# chr5:154627638-154628386      5  154627638  154628386       chr5  154627638
# ...                         ...        ...        ...        ...        ...
# chr15:71448618-71449096      15   71448618   71449096      chr15   71448618
# chr15:71792584-71792805      15   71792584   71792805      chr15   71792584
# chr15:75810000-75810429      15   75810000   75810429      chr15   75810000
# chr15:76805231-76805523      15   76805231   76805523      chr15   76805231
# chr15:77885067-77885439      15   77885067   77885439      chr15   77885067
#
#                                 End  n_cells
# chr2:148881654-148881927  148881927       93
# chr8:99495798-99496023     99496023       60
# chr22:21735444-21736416    21736416       36
# chr3:28241304-28242015     28242015       19
# chr5:154627638-154628386  154628386       22
# ...                             ...      ...
# chr15:71448618-71449096    71449096        3
# chr15:71792584-71792805    71792805        7
# chr15:75810000-75810429    75810429        3
# chr15:76805231-76805523    76805523        7
# chr15:77885067-77885439    77885439        7
#
# [56549 rows x 9 columns]

# %%
for celltype in celltypes:
    print(celltype)
    if celltype == 'BJ' :
        marker_gene = 'PDGFRA' #fibroblast
    elif celltype == 'H1':
        marker_gene = 'CD9'
    elif celltype == 'GM12878':
        marker_gene = 'CD38'
    elif celltype =='K562':
        marker_gene = 'CD38'
    atac_adata, rna_adata = preprocessing_adata_celltype(atac_anndata,rna_anndata,gene_file=gene_file,celltype = celltype)
    
    print("Processing multimodal")
    preprocess_multimodal(rna_adata,atac_adata)
    print("CRE-gene relationship")
    folder_path = f"./results_{celltype}/CRE_gene"

    run_gridot_cell_population(rna_adata,atac_adata,schema_reference='rna',marker_gene = marker_gene,distance_threshold=distance_threshold,device = device,folder_path = folder_path)
# Out:
# BJ
# Pre-processing scATAC-seq...
# AnnData object with n_obs × n_vars = 258 × 56549
#     obs: 'label', 'n_genes', 'orig.ident'
#     var: '0', 'features', 'chr_no', 'start', 'end', 'Chromosome', 'Start', 'End', 'n_cells'
# Pre-processing scRNA-seq...
# AnnData object with n_obs × n_vars = 258 × 8326
#     obs: '0', 'orig.ident', 'label', 'n_genes'
#     var: '0', 'n_cells', 'features'
# Adding start site to meta file...
# Processing multimodal
# CRE-gene relationship
# Identifying candidate pairs within 100000.0 bp
# 67784
# Running quadratic program... done.
# Cell with highest PDGFRA expression: ('CACTTTCGGCAT', 8)
# Expression level: [6.158457]
# WARNING: Trying to run `tl.dpt` without prior call of `tl.diffmap`. Falling back to `tl.diffmap` with default parameters.
# Epoch 0 (1.73 seconds): train loss 260.71
# Epoch Inference (5.50 seconds): test loss 257.98
# Total Time: 7.472091436386108 seconds
# Folder created at: ./results_BJ/CRE_gene
# H1
# Pre-processing scATAC-seq...
# AnnData object with n_obs × n_vars = 309 × 63567
#     obs: 'label', 'n_genes', 'orig.ident'
#     var: '0', 'features', 'chr_no', 'start', 'end', 'Chromosome', 'Start', 'End', 'n_cells'
# Pre-processing scRNA-seq...
# AnnData object with n_obs × n_vars = 309 × 9055
#     obs: '0', 'orig.ident', 'label', 'n_genes'
#     var: '0', 'n_cells', 'features'
# Adding start site to meta file...
# Processing multimodal
# CRE-gene relationship
# Identifying candidate pairs within 100000.0 bp
# 73403
# Running quadratic program... done.
# Cell with highest CD9 expression: ('AATTCACGTATG', 166)
# Expression level: [6.497154]
# WARNING: Trying to run `tl.dpt` without prior call of `tl.diffmap`. Falling back to `tl.diffmap` with default parameters.
# Epoch 0 (1.32 seconds): train loss 269.96
# Epoch Inference (5.98 seconds): test loss 266.52
# Total Time: 7.478005409240723 seconds
# Folder created at: ./results_H1/CRE_gene
# GM12878
# Pre-processing scATAC-seq...
# AnnData object with n_obs × n_vars = 116 × 17461
#     obs: 'label', 'n_genes', 'orig.ident'
#     var: '0', 'features', 'chr_no', 'start', 'end', 'Chromosome', 'Start', 'End', 'n_cells'
# Pre-processing scRNA-seq...
# AnnData object with n_obs × n_vars = 116 × 3830
#     obs: '0', 'orig.ident', 'label', 'n_genes'
#     var: '0', 'n_cells', 'features'
# Adding start site to meta file...
# Processing multimodal
# CRE-gene relationship
# Identifying candidate pairs within 100000.0 bp
# 12647
# Running quadratic program... done.
# Cell with highest CD38 expression: ('TCGCATCGCTGC', 62)
# Expression level: [5.622146]
# WARNING: Trying to run `tl.dpt` without prior call of `tl.diffmap`. Falling back to `tl.diffmap` with default parameters.
# Epoch 0 (0.18 seconds): train loss 67.83
# Epoch Inference (1.00 seconds): test loss 67.44
# Total Time: 1.2307779788970947 seconds
# Folder created at: ./results_GM12878/CRE_gene
# K562
# Pre-processing scATAC-seq...
# AnnData object with n_obs × n_vars = 150 × 14922
#     obs: 'label', 'n_genes', 'orig.ident'
#     var: '0', 'features', 'chr_no', 'start', 'end', 'Chromosome', 'Start', 'End', 'n_cells'
# Pre-processing scRNA-seq...
# AnnData object with n_obs × n_vars = 150 × 6365
#     obs: '0', 'orig.ident', 'label', 'n_genes'
#     var: '0', 'n_cells', 'features'
# Adding start site to meta file...
# Processing multimodal
# CRE-gene relationship
# Identifying candidate pairs within 100000.0 bp
# 17467
# Running quadratic program... done.
# Gene CD38 not found in the dataset.
# WARNING: Trying to run `tl.dpt` without prior call of `tl.diffmap`. Falling back to `tl.diffmap` with default parameters.
# Epoch 0 (0.26 seconds): train loss 79.11
# Epoch Inference (1.40 seconds): test loss 78.32
# Total Time: 1.7470595836639404 seconds
# Folder created at: ./results_K562/CRE_gene
